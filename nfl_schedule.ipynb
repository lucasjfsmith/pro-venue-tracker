# %%
import pandas as pd

# %%
#Read in csv
csv_file_path = "Resources/nfl-2023-UTC.csv"
nfl_df = pd.read_csv(csv_file_path)

# %%
nfl_df.head()
# Out:
#    Match Number  Round Number              Date  \
# 0            16             1  08/09/2023 00:20
# 1             8             1  10/09/2023 17:00
# 2             9             1  10/09/2023 17:00
# 3            10             1  10/09/2023 17:00
# 4            11             1  10/09/2023 17:00
#
#                           Location           Home Team             Away Team  \
# 0  GEHA Field at Arrowhead Stadium  Kansas City Chiefs         Detroit Lions
# 1            Mercedes-Benz Stadium     Atlanta Falcons     Carolina Panthers
# 2                 M&T Bank Stadium    Baltimore Ravens        Houston Texans
# 3         Cleveland Browns Stadium    Cleveland Browns    Cincinnati Bengals
# 4                Lucas Oil Stadium  Indianapolis Colts  Jacksonville Jaguars
#
#    Result
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
#Split date column into date and time
nfl_df[['Date', 'Time']] = nfl_df['Date'].str.split(' ', 1, expand=True)
nfl_df.head()
# Out:
# C:\Users\jeffi\AppData\Local\Temp\ipykernel_31720\2803032143.py:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   nfl_df[['Date', 'Time']] = nfl_df['Date'].str.split(' ', 1, expand=True)
#    Match Number  Round Number        Date                         Location  \
# 0            16             1  08/09/2023  GEHA Field at Arrowhead Stadium
# 1             8             1  10/09/2023            Mercedes-Benz Stadium
# 2             9             1  10/09/2023                 M&T Bank Stadium
# 3            10             1  10/09/2023         Cleveland Browns Stadium
# 4            11             1  10/09/2023                Lucas Oil Stadium
#
#             Home Team             Away Team  Result   Time
# 0  Kansas City Chiefs         Detroit Lions     NaN  00:20
# 1     Atlanta Falcons     Carolina Panthers     NaN  17:00
# 2    Baltimore Ravens        Houston Texans     NaN  17:00
# 3    Cleveland Browns    Cincinnati Bengals     NaN  17:00
# 4  Indianapolis Colts  Jacksonville Jaguars     NaN  17:00

# %%
#change date format
nfl_df['Date'] = pd.to_datetime(nfl_df['Date'], format='%d/%m/%Y')
nfl_df['Date'] = nfl_df['Date'].dt.strftime('%m/%d/%Y')
nfl_df.head()
# Out:
#    Match Number  Round Number        Date                         Location  \
# 0            16             1  09/08/2023  GEHA Field at Arrowhead Stadium
# 1             8             1  09/10/2023            Mercedes-Benz Stadium
# 2             9             1  09/10/2023                 M&T Bank Stadium
# 3            10             1  09/10/2023         Cleveland Browns Stadium
# 4            11             1  09/10/2023                Lucas Oil Stadium
#
#             Home Team             Away Team  Result   Time
# 0  Kansas City Chiefs         Detroit Lions     NaN  00:20
# 1     Atlanta Falcons     Carolina Panthers     NaN  17:00
# 2    Baltimore Ravens        Houston Texans     NaN  17:00
# 3    Cleveland Browns    Cincinnati Bengals     NaN  17:00
# 4  Indianapolis Colts  Jacksonville Jaguars     NaN  17:00

# %%
# Rename column
new_column_name = 'Week Number'
nfl_df.rename(columns={'Round Number': new_column_name}, inplace=True)
nfl_df.head()
# Out:
#    Match Number  Week Number        Date                         Location  \
# 0            16            1  09/08/2023  GEHA Field at Arrowhead Stadium
# 1             8            1  09/10/2023            Mercedes-Benz Stadium
# 2             9            1  09/10/2023                 M&T Bank Stadium
# 3            10            1  09/10/2023         Cleveland Browns Stadium
# 4            11            1  09/10/2023                Lucas Oil Stadium
#
#             Home Team             Away Team  Result   Time
# 0  Kansas City Chiefs         Detroit Lions     NaN  00:20
# 1     Atlanta Falcons     Carolina Panthers     NaN  17:00
# 2    Baltimore Ravens        Houston Texans     NaN  17:00
# 3    Cleveland Browns    Cincinnati Bengals     NaN  17:00
# 4  Indianapolis Colts  Jacksonville Jaguars     NaN  17:00

# %%
#changing time zone to central time zone (CST)
nfl_df['Time'] = pd.to_datetime(nfl_df['Time'], utc=True)
# Convert the time column to CST time zone
nfl_df['CST Gametime'] = nfl_df['Time'].dt.tz_convert('America/Chicago')

# Only show the time in 12 hr format
nfl_df['CST Gametime'] = nfl_df['CST Gametime'].apply(lambda x: x.strftime('%I:%M %p'))

# Print the DataFrame
nfl_df.head()
# Out:
#    Match Number  Week Number        Date                         Location  \
# 0            16            1  09/08/2023  GEHA Field at Arrowhead Stadium
# 1             8            1  09/10/2023            Mercedes-Benz Stadium
# 2             9            1  09/10/2023                 M&T Bank Stadium
# 3            10            1  09/10/2023         Cleveland Browns Stadium
# 4            11            1  09/10/2023                Lucas Oil Stadium
#
#             Home Team             Away Team  Result                      Time  \
# 0  Kansas City Chiefs         Detroit Lions     NaN 2023-08-07 00:20:00+00:00
# 1     Atlanta Falcons     Carolina Panthers     NaN 2023-08-07 17:00:00+00:00
# 2    Baltimore Ravens        Houston Texans     NaN 2023-08-07 17:00:00+00:00
# 3    Cleveland Browns    Cincinnati Bengals     NaN 2023-08-07 17:00:00+00:00
# 4  Indianapolis Colts  Jacksonville Jaguars     NaN 2023-08-07 17:00:00+00:00
#
#   CST Gametime
# 0     07:20 PM
# 1     12:00 PM
# 2     12:00 PM
# 3     12:00 PM
# 4     12:00 PM

# %%
#drop old time column
nfl_df = nfl_df.drop(columns=['Time'])
nfl_df.head()
# Out:
#    Match Number  Week Number        Date                         Location  \
# 0            16            1  09/08/2023  GEHA Field at Arrowhead Stadium
# 1             8            1  09/10/2023            Mercedes-Benz Stadium
# 2             9            1  09/10/2023                 M&T Bank Stadium
# 3            10            1  09/10/2023         Cleveland Browns Stadium
# 4            11            1  09/10/2023                Lucas Oil Stadium
#
#             Home Team             Away Team  Result CST Gametime
# 0  Kansas City Chiefs         Detroit Lions     NaN     07:20 PM
# 1     Atlanta Falcons     Carolina Panthers     NaN     12:00 PM
# 2    Baltimore Ravens        Houston Texans     NaN     12:00 PM
# 3    Cleveland Browns    Cincinnati Bengals     NaN     12:00 PM
# 4  Indianapolis Colts  Jacksonville Jaguars     NaN     12:00 PM

# %%
#drop Match Number column
nfl_df = nfl_df.drop(columns=["Match Number"])
nfl_df.head()
# Out:
#    Week Number        Date                         Location  \
# 0            1  09/08/2023  GEHA Field at Arrowhead Stadium
# 1            1  09/10/2023            Mercedes-Benz Stadium
# 2            1  09/10/2023                 M&T Bank Stadium
# 3            1  09/10/2023         Cleveland Browns Stadium
# 4            1  09/10/2023                Lucas Oil Stadium
#
#             Home Team             Away Team  Result CST Gametime
# 0  Kansas City Chiefs         Detroit Lions     NaN     07:20 PM
# 1     Atlanta Falcons     Carolina Panthers     NaN     12:00 PM
# 2    Baltimore Ravens        Houston Texans     NaN     12:00 PM
# 3    Cleveland Browns    Cincinnati Bengals     NaN     12:00 PM
# 4  Indianapolis Colts  Jacksonville Jaguars     NaN     12:00 PM
