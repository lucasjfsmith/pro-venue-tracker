# %%
import psycopg2

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

from flask import Flask, jsonify
from api_key import postgres_pw

# %%
engine = create_engine(f'postgresql+psycopg2://postgres:{postgres_pw}@localhost:5432/project_3')

# %%
Base = automap_base()

# %%
Base.prepare(autoload_with=engine)

# %%
Venue = Base.classes.venue
Team = Base.classes.team
League = Base.classes.league

# %%
session = Session(engine)

results = session.query(Venue.venue_id, Venue.venue_name, Venue.venue_address, Venue.venue_lat, Venue.venue_lon).all()




all_venues = []
for result in results:
    venue_dict = {}
    venue_dict["venue_id"] = result[0]
    venue_dict["venue_name"] = result[1] 
    venue_dict["venue_address"] = result[2]
    venue_dict["venue_lat"] = float(result[3])
    venue_dict["venue_lon"] = float(result[4])
    all_venues.append(venue_dict)

all_venues
# Out:
# [{'venue_id': 1,
#   'venue_name': 'American Airlines Center',
#   'venue_address': '2500 Victory Avenue, Dallas, TX 75219, United States of America',
#   'venue_lat': 32.7905076,
#   'venue_lon': -96.81027213460834},
#  {'venue_id': 2,
#   'venue_name': 'Amway Center',
#   'venue_address': 'Hughey Avenue, Orlando, FL 32801, United States of America',
#   'venue_lat': 28.53927385,
#   'venue_lon': -81.38400713924818},
#  {'venue_id': 3,
#   'venue_name': 'AT&T Center',
#   'venue_address': 'San Antonio, TX 78219, United States of America',
#   'venue_lat': 29.4270504,
#   'venue_lon': -98.43750706398404},
#  {'venue_id': 4,
#   'venue_name': 'Ball Arena',
#   'venue_address': '1000 Chopper Circle, Denver, CO 80204, United States of America',
#   'venue_lat': 39.748683799999995,
#   'venue_lon': -105.00754401780362},
#  {'venue_id': 5,
#   'venue_name': 'Barclays Center',
#   'venue_address': '620 Atlantic Avenue, New York, NY 11217, United States of America',
#   'venue_lat': 40.68251055,
#   'venue_lon': -73.97525186658912},
#  {'venue_id': 6,
#   'venue_name': 'Capital One Arena',
#   'venue_address': '601 F Street Northwest, Washington, DC 20004, United States of America',
#   'venue_lat': 38.8981883,
#   'venue_lon': -77.0209377602636},
#  {'venue_id': 7,
#   'venue_name': 'Chase Center',
#   'venue_address': '1 Warriors Way, San Francisco, CA 94158, United States of America',
#   'venue_lat': 37.767892700000004,
#   'venue_lon': -122.38740721330376},
#  {'venue_id': 8,
#   'venue_name': 'Crypto.com Arena',
#   'venue_address': '1111 Figueroa Street, Los Angeles, CA 90015, United States of America',
#   'venue_lat': 34.0430046,
#   'venue_lon': -118.26705260279402},
#  {'venue_id': 9,
#   'venue_name': 'FedExForum',
#   'venue_address': '191 Beale Street, Memphis, TN 38103, United States of America',
#   'venue_lat': 35.1382401,
#   'venue_lon': -90.05069457768097},
#  {'venue_id': 10,
#   'venue_name': 'Fiserv Forum',
#   'venue_address': '1111 North Vel R. Phillips Avenue, Milwaukee, WI 53203, United States of America',
#   'venue_lat': 43.04500955,
#   'venue_lon': -87.91748710581575},
#  {'venue_id': 11,
#   'venue_name': 'Footprint Center',
#   'venue_address': 'East Jefferson Street, Phoenix, AZ 85004, United States of America',
#   'venue_lat': 33.4460392,
#   'venue_lon': -112.07110129629386},
#  {'venue_id': 12,
#   'venue_name': 'Miami-Dade Arena',
#   'venue_address': '601 Biscayne Boulevard, Miami, FL 33132, United States of America',
#   'venue_lat': 25.781359549999998,
#   'venue_lon': -80.18794351626137},
#  {'venue_id': 13,
#   'venue_name': 'Gainbridge Fieldhouse',
#   'venue_address': '125 South Pennsylvania Street, Indianapolis, IN 46204, United States of America',
#   'venue_lat': 39.7639331,
#   'venue_lon': -86.15550794973416},
#  {'venue_id': 14,
#   'venue_name': 'Golden 1 Center',
#   'venue_address': '500 L Street, Sacramento, CA 95814, United States of America',
#   'venue_lat': 38.58014045,
#   'venue_lon': -121.49950076409176},
#  {'venue_id': 15,
#   'venue_name': 'Little Caesars Arena',
#   'venue_address': '2645 Woodward Avenue, Detroit, MI 48201, United States of America',
#   'venue_lat': 42.34092995,
#   'venue_lon': -83.05516216701272},
#  {'venue_id': 16,
#   'venue_name': 'Madison Square Garden',
#   'venue_address': '4 Pennsylvania Plaza, New York, NY 10001, United States of America',
#   'venue_lat': 40.750512900000004,
#   'venue_lon': -73.99351594545152},
#  {'venue_id': 17,
#   'venue_name': 'Moda Center',
#   'venue_address': 'North Multnomah Street, Portland, OR 97240, United States of America',
#   'venue_lat': 45.5315787,
#   'venue_lon': -122.66683365218687},
#  {'venue_id': 18,
#   'venue_name': 'Paycom Center',
#   'venue_address': '100 West Reno Avenue, Oklahoma City, OK 73102, United States of America',
#   'venue_lat': 35.46339605,
#   'venue_lon': -97.51508150130435},
#  {'venue_id': 19,
#   'venue_name': 'Rocket Mortgage FieldHouse',
#   'venue_address': '1 Huron Road East, Cleveland, OH 44115, United States of America',
#   'venue_lat': 41.4966862,
#   'venue_lon': -81.68857538921003},
#  {'venue_id': 20,
#   'venue_name': 'Scotiabank Arena',
#   'venue_address': '40 Bay Street, Old Toronto, ON M5J 2J2, Canada',
#   'venue_lat': 43.64343375,
#   'venue_lon': -79.37907772483726},
#  {'venue_id': 21,
#   'venue_name': 'Smoothie King Center',
#   'venue_address': '2500 Howard Avenue, New Orleans, LA 70012, United States of America',
#   'venue_lat': 29.94903925,
#   'venue_lon': -90.08206899587637},
#  {'venue_id': 22,
#   'venue_name': 'Spectrum Center',
#   'venue_address': '333 East Trade Street, Charlotte, NC 28202, United States of America',
#   'venue_lat': 35.225098,
#   'venue_lon': -80.83915411814897},
#  {'venue_id': 23,
#   'venue_name': 'State Farm Arena',
#   'venue_address': '1 State Farm Drive, Atlanta, GA 30303, United States of America',
#   'venue_lat': 33.7573698,
#   'venue_lon': -84.39638483503104},
#  {'venue_id': 24,
#   'venue_name': 'Target Center',
#   'venue_address': 'North 6th Street, Minneapolis, MN 55401, United States of America',
#   'venue_lat': 44.979512650000004,
#   'venue_lon': -93.27609502567992},
#  {'venue_id': 25,
#   'venue_name': 'TD Garden',
#   'venue_address': '100 Legends Way, Boston, MA 02114, United States of America',
#   'venue_lat': 42.3662986,
#   'venue_lon': -71.06216222263835},
#  {'venue_id': 26,
#   'venue_name': 'Toyota Center',
#   'venue_address': '1510 Polk Street, Houston, TX 77010, United States of America',
#   'venue_lat': 29.75074725,
#   'venue_lon': -95.36223151477087},
#  {'venue_id': 27,
#   'venue_name': 'United Center',
#   'venue_address': '1901 West Madison Street, Chicago, IL 60612, United States of America',
#   'venue_lat': 41.88068305,
#   'venue_lon': -87.67418510441388},
#  {'venue_id': 28,
#   'venue_name': 'Vivint Arena',
#   'venue_address': 'South Temple, Salt Lake City, UT 84180, United States of America',
#   'venue_lat': 40.76832735,
#   'venue_lon': -111.90105507486473},
#  {'venue_id': 29,
#   'venue_name': 'Wells Fargo Center',
#   'venue_address': 'Zinkoff Boulevard, Philadelphia, PA 19112, United States of America',
#   'venue_lat': 39.901100400000004,
#   'venue_lon': -75.17201654615069},
#  {'venue_id': 30,
#   'venue_name': 'Allegiant Stadium',
#   'venue_address': '3333 Al Davis Way, Las Vegas, NV 89118, United States of America',
#   'venue_lat': 36.09083455,
#   'venue_lon': -115.18343206671804},
#  {'venue_id': 31,
#   'venue_name': 'Arrowhead Stadium',
#   'venue_address': '1 Arrowhead Drive, Kansas City, MO 64129, United States of America',
#   'venue_lat': 39.04894045,
#   'venue_lon': -94.48499381102714},
#  {'venue_id': 32,
#   'venue_name': 'AT&T Stadium',
#   'venue_address': '900 East Randol Mill Road, Arlington, TX 76011, United States of America',
#   'venue_lat': 32.74785025,
#   'venue_lon': -97.09283370737742},
#  {'venue_id': 33,
#   'venue_name': 'Bank of America Stadium',
#   'venue_address': '800 South Mint Street, Charlotte, NC 28202, United States of America',
#   'venue_lat': 35.225737,
#   'venue_lon': -80.8527666409835},
#  {'venue_id': 34,
#   'venue_name': "Caesar's Superdome",
#   'venue_address': '1500 Sugar Bowl Drive, New Orleans, LA 70113, United States of America',
#   'venue_lat': 29.9510856,
#   'venue_lon': -90.08122023028636},
#  {'venue_id': 35,
#   'venue_name': 'Empower Field',
#   'venue_address': '1701 Mile High Stadium Circle, Denver, CO 80204, United States of America',
#   'venue_lat': 39.743952,
#   'venue_lon': -105.01922281236835},
#  {'venue_id': 36,
#   'venue_name': 'FedExField',
#   'venue_address': '1600 Sean Taylor Road, Landover, MD 20785, United States of America',
#   'venue_lat': 38.9077002,
#   'venue_lon': -76.86332608690218},
#  {'venue_id': 37,
#   'venue_name': 'FirstEnergy Stadium',
#   'venue_address': '100 Alfred Lerner Way, Cleveland, OH 44113, United States of America',
#   'venue_lat': 41.5060559,
#   'venue_lon': -81.69971184525946},
#  {'venue_id': 38,
#   'venue_name': 'Ford Field',
#   'venue_address': 'Brush Street, Detroit, MI 48226, United States of America',
#   'venue_lat': 42.33995675,
#   'venue_lon': -83.04561657403696},
#  {'venue_id': 39,
#   'venue_name': 'Gillette Stadium',
#   'venue_address': 'Patriot Place, Foxborough, MA 02071, United States of America',
#   'venue_lat': 42.091252600000004,
#   'venue_lon': -71.2644646105907},
#  {'venue_id': 40,
#   'venue_name': 'Hard Rock Stadium',
#   'venue_address': '105, Lake Lucerne, FL 33056, United States of America',
#   'venue_lat': 25.95790315,
#   'venue_lon': -80.23884973967523},
#  {'venue_id': 41,
#   'venue_name': 'Acrisure Stadium',
#   'venue_address': 'North Shore Drive, Pittsburgh, PA 15290, United States of America',
#   'venue_lat': 40.44671645,
#   'venue_lon': -80.01575493349428},
#  {'venue_id': 42,
#   'venue_name': 'Highmark Blue Cross Blue Shield Stadium',
#   'venue_address': '1 Bills Drive, Orchard Park, NY 14127, United States of America',
#   'venue_lat': 42.7737131,
#   'venue_lon': -78.78690321060253},
#  {'venue_id': 43,
#   'venue_name': 'Lambeau Field',
#   'venue_address': '1265 Lombardi Avenue, Green Bay, WI 54304, United States of America',
#   'venue_lat': 44.50095825,
#   'venue_lon': -88.06103404376007},
#  {'venue_id': 44,
#   'venue_name': 'Levi’s Stadium',
#   'venue_address': '4900 Marie P. DeBartolo Way, Santa Clara, CA 95054, United States of America',
#   'venue_lat': 37.403158250000004,
#   'venue_lon': -121.96983144425579},
#  {'venue_id': 45,
#   'venue_name': 'Lincoln Financial Field',
#   'venue_address': 'South Darien Street, Philadelphia, PA 19148, United States of America',
#   'venue_lat': 39.9009099,
#   'venue_lon': -75.16748915605905},
#  {'venue_id': 46,
#   'venue_name': 'Lucas Oil Stadium',
#   'venue_address': 'West Henry Street, Indianapolis, IN 46225, United States of America',
#   'venue_lat': 39.7590621,
#   'venue_lon': -86.16383761053042},
#  {'venue_id': 47,
#   'venue_name': 'Lumen Field',
#   'venue_address': '800 Occidental Avenue South, Seattle, WA 98134, United States of America',
#   'venue_lat': 47.5953459,
#   'venue_lon': -122.33164431196111},
#  {'venue_id': 48,
#   'venue_name': 'M&T Bank Stadium',
#   'venue_address': '1101 Russell Street, Baltimore, MD 21230, United States of America',
#   'venue_lat': 39.2779664,
#   'venue_lon': -76.62380930835468},
#  {'venue_id': 49,
#   'venue_name': 'Mercedes-Benz Stadium',
#   'venue_address': '1414 Andrew Young International Boulevard, Atlanta, GA 30313, United States of America',
#   'venue_lat': 33.7554123,
#   'venue_lon': -84.40084932004368},
#  {'venue_id': 50,
#   'venue_name': 'MetLife Stadium',
#   'venue_address': 'Road D, East Rutherford, NJ 07072, United States of America',
#   'venue_lat': 40.81352375,
#   'venue_lon': -74.07340074891175},
#  {'venue_id': 51,
#   'venue_name': 'Nissan Stadium',
#   'venue_address': 'Victory Avenue, Nashville-Davidson, TN 37213, United States of America',
#   'venue_lat': 36.16652355,
#   'venue_lon': -86.77131480177009},
#  {'venue_id': 52,
#   'venue_name': 'NRG Stadium',
#   'venue_address': '1 NRG Parkway, Houston, TX 77054, United States of America',
#   'venue_lat': 29.6848581,
#   'venue_lon': -95.41080145326987},
#  {'venue_id': 53,
#   'venue_name': 'Paycor Stadium',
#   'venue_address': '1 West Pete Rose Way, Cincinnati, OH 45203, United States of America',
#   'venue_lat': 39.0954645,
#   'venue_lon': -84.5160488350198},
#  {'venue_id': 54,
#   'venue_name': 'Raymond James Stadium',
#   'venue_address': 'West Tampa Bay Boulevard, Tampa, FL 33607, United States of America',
#   'venue_lat': 27.97597925,
#   'venue_lon': -82.50421799673616},
#  {'venue_id': 55,
#   'venue_name': 'SoFi Stadium',
#   'venue_address': '1001 Champion Drive, Inglewood, CA 90301, United States of America',
#   'venue_lat': 33.95340735,
#   'venue_lon': -118.33900981025587},
#  {'venue_id': 56,
#   'venue_name': 'Soldier Field',
#   'venue_address': '425 East McFetridge Drive, Chicago, IL 60605, United States of America',
#   'venue_lat': 41.86245145,
#   'venue_lon': -87.61671514704074},
#  {'venue_id': 57,
#   'venue_name': 'State Farm Stadium',
#   'venue_address': '1 West Cardinals Drive, Glendale, AZ 85305, United States of America',
#   'venue_lat': 33.52779565,
#   'venue_lon': -112.26267190264335},
#  {'venue_id': 58,
#   'venue_name': 'TIAA Bank Field',
#   'venue_address': '1 Gator Bowl Boulevard, Jacksonville, FL 32202, United States of America',
#   'venue_lat': 30.32398105,
#   'venue_lon': -81.63730457034035},
#  {'venue_id': 59,
#   'venue_name': 'US Bank Stadium',
#   'venue_address': '401 Chicago Avenue South, Minneapolis, MN 55415, United States of America',
#   'venue_lat': 44.97361545,
#   'venue_lon': -93.25746628273055},
#  {'venue_id': 60,
#   'venue_name': 'Amalie Arena',
#   'venue_address': '401 Channelside Drive, Tampa, FL 33602, United States of America',
#   'venue_lat': 27.942704,
#   'venue_lon': -82.45189031562487},
#  {'venue_id': 61,
#   'venue_name': 'Centre Bell',
#   'venue_address': 'Place des Canadiens, Montreal, QC H3C 1B4, Canada',
#   'venue_lat': 45.49605985,
#   'venue_lon': -73.56922527683774},
#  {'venue_id': 62,
#   'venue_name': 'Bridgestone Arena',
#   'venue_address': '501 6th Avenue South, Nashville-Davidson, TN 37203, United States of America',
#   'venue_lat': 36.1589806,
#   'venue_lon': -86.77838189265074},
#  {'venue_id': 63,
#   'venue_name': 'Canada Life Centre',
#   'venue_address': '300 Portage Avenue, Winnipeg, MB R3B 2B9, Canada',
#   'venue_lat': 49.8925737,
#   'venue_lon': -97.1437218346315},
#  {'venue_id': 64,
#   'venue_name': 'Canadian Tire Centre',
#   'venue_address': '1000 Palladium Drive, Ottawa, ON K2V 1E2, Canada',
#   'venue_lat': 45.296906899999996,
#   'venue_lon': -75.92689732572379},
#  {'venue_id': 65,
#   'venue_name': 'Climate Pledge Arena',
#   'venue_address': '334 1st Avenue North, Seattle, WA 98109, United States of America',
#   'venue_lat': 47.6219014,
#   'venue_lon': -122.353990491486},
#  {'venue_id': 66,
#   'venue_name': 'Enterprise Center',
#   'venue_address': '1401 Clark Avenue, St. Louis, MO 63103, United States of America',
#   'venue_lat': 38.62680845,
#   'venue_lon': -90.20263932150607},
#  {'venue_id': 67,
#   'venue_name': 'FLA Live Arena',
#   'venue_address': '1 Northwest 137th Way, Sunrise, FL 33323, United States of America',
#   'venue_lat': 26.15837015,
#   'venue_lon': -80.3254288749938},
#  {'venue_id': 68,
#   'venue_name': 'Gila River Arena',
#   'venue_address': '9400 West Maryland Avenue, Glendale, AZ 85305, United States of America',
#   'venue_lat': 33.53196065,
#   'venue_lon': -112.26124059182274},
#  {'venue_id': 69,
#   'venue_name': 'Honda Center',
#   'venue_address': '2695 East Katella Avenue, Anaheim, CA 92806, United States of America',
#   'venue_lat': 33.80783155,
#   'venue_lon': -117.876533959295},
#  {'venue_id': 70,
#   'venue_name': 'KeyBank Center',
#   'venue_address': 'Washington Street, Buffalo, NY 14203, United States of America',
#   'venue_lat': 42.87514665,
#   'venue_lon': -78.87663585570175},
#  {'venue_id': 71,
#   'venue_name': 'Nationwide Arena',
#   'venue_address': '200 West Nationwide Boulevard, Columbus, OH 43215, United States of America',
#   'venue_lat': 39.9691873,
#   'venue_lon': -83.00608002061449},
#  {'venue_id': 72,
#   'venue_name': 'Carter-Finley Stadium',
#   'venue_address': 'E. Stephen Stroud Way, Raleigh, NC 27607, United States of America',
#   'venue_lat': 35.800846449999995,
#   'venue_lon': -78.71960451582763},
#  {'venue_id': 73,
#   'venue_name': 'PPG Paints Arena',
#   'venue_address': '1001 Fifth Avenue, Pittsburgh, PA 15262, United States of America',
#   'venue_lat': 40.439621700000004,
#   'venue_lon': -79.98950569382804},
#  {'venue_id': 74,
#   'venue_name': 'Prudential Center',
#   'venue_address': '25 Lafayette Street, Newark, NJ 07102, United States of America',
#   'venue_lat': 40.7336045,
#   'venue_lon': -74.17106309834053},
#  {'venue_id': 75,
#   'venue_name': 'Rogers Arena',
#   'venue_address': '800 Griffiths Way, Vancouver, BC V6B, Canada',
#   'venue_lat': 49.2779085,
#   'venue_lon': -123.10894170979472},
#  {'venue_id': 76,
#   'venue_name': 'Rogers Place',
#   'venue_address': '10220 104 Avenue NW, Edmonton, AB T5J 4Y8, Canada',
#   'venue_lat': 53.5467936,
#   'venue_lon': -113.49779461115837},
#  {'venue_id': 77,
#   'venue_name': 'SAP Center at San Jose',
#   'venue_address': '525 West Santa Clara Street, San Jose, CA 95113, United States of America',
#   'venue_lat': 37.33286035,
#   'venue_lon': -121.90122465574646},
#  {'venue_id': 78,
#   'venue_name': 'Scotiabank Saddledome',
#   'venue_address': '555 Saddledome Rise SE, Calgary, AB T2G 2W1, Canada',
#   'venue_lat': 51.037412399999994,
#   'venue_lon': -114.05196415720093},
#  {'venue_id': 79,
#   'venue_name': 'T-Mobile Arena',
#   'venue_address': 'Frank Sinatra Drive, Paradise, NV 89158, United States of America',
#   'venue_lat': 36.102678049999994,
#   'venue_lon': -115.17822391490796},
#  {'venue_id': 80,
#   'venue_name': 'UBS Arena',
#   'venue_address': '2400 Hempstead Turnpike, Village of Floral Park, NY 11001, United States of America',
#   'venue_lat': 40.7116942,
#   'venue_lon': -73.72592286769509},
#  {'venue_id': 81,
#   'venue_name': 'Xcel Energy Center',
#   'venue_address': '7th Street West, Saint Paul, MN 55155, United States of America',
#   'venue_lat': 44.9447659,
#   'venue_lon': -93.10108511954809},
#  {'venue_id': 82,
#   'venue_name': 'American Family Field',
#   'venue_address': '1 Brewers Way, Milwaukee, WI 53214, United States of America',
#   'venue_lat': 43.0280619,
#   'venue_lon': -87.97209586840818},
#  {'venue_id': 83,
#   'venue_name': 'Angel Stadium of Anaheim',
#   'venue_address': '2000 East Gene Autry Way, Anaheim, CA 92806, United States of America',
#   'venue_lat': 33.8002599,
#   'venue_lon': -117.88174262759796},
#  {'venue_id': 84,
#   'venue_name': 'Busch Stadium',
#   'venue_address': '700 Clark Avenue, St. Louis, MO 63101, United States of America',
#   'venue_lat': 38.6225538,
#   'venue_lon': -90.19392193458768},
#  {'venue_id': 85,
#   'venue_name': 'Chase Field',
#   'venue_address': 'East Jefferson Street, Phoenix, AZ 85004, United States of America',
#   'venue_lat': 33.44548555,
#   'venue_lon': -112.06669283293144},
#  {'venue_id': 86,
#   'venue_name': 'Citi Field',
#   'venue_address': '41 Seaver Way, New York, NY 11368, United States of America',
#   'venue_lat': 40.757277849999994,
#   'venue_lon': -73.84587884942417},
#  {'venue_id': 87,
#   'venue_name': 'Citizens Bank Park',
#   'venue_address': 'Pattison Avenue, Philadelphia, PA 19145, United States of America',
#   'venue_lat': 39.905885749999996,
#   'venue_lon': -75.16541101747245},
#  {'venue_id': 88,
#   'venue_name': 'Comerica Park',
#   'venue_address': 'Brush Street, Detroit, MI 48226, United States of America',
#   'venue_lat': 42.33915895,
#   'venue_lon': -83.0496248178274},
#  {'venue_id': 89,
#   'venue_name': 'Coors Field',
#   'venue_address': '2001 Blake Street, Denver, CO 80205, United States of America',
#   'venue_lat': 39.7560314,
#   'venue_lon': -104.99292855531493},
#  {'venue_id': 90,
#   'venue_name': 'Dodger Stadium',
#   'venue_address': '1000 Vin Scully Avenue, Los Angeles, CA 90012, United States of America',
#   'venue_lat': 34.0736263,
#   'venue_lon': -118.23897581574036},
#  {'venue_id': 91,
#   'venue_name': 'Fenway Park',
#   'venue_address': '4 Jersey Street, Boston, MA 02115, United States of America',
#   'venue_lat': 42.3464621,
#   'venue_lon': -71.0971002033302},
#  {'venue_id': 92,
#   'venue_name': 'Globe Life Field',
#   'venue_address': 'Cowboys Way, Arlington, TX 76011, United States of America',
#   'venue_lat': 32.74760655,
#   'venue_lon': -97.08410630166019},
#  {'venue_id': 93,
#   'venue_name': 'Great American Ball Park',
#   'venue_address': 'Ohio River Trail, Cincinnati, OH 45202, United States of America',
#   'venue_lat': 39.097248449999995,
#   'venue_lon': -84.50662325533993},
#  {'venue_id': 94,
#   'venue_name': 'Guaranteed Rate Field',
#   'venue_address': '333 West 35th Street, Chicago, IL 60616, United States of America',
#   'venue_lat': 41.8300162,
#   'venue_lon': -87.63256264837347},
#  {'venue_id': 95,
#   'venue_name': 'Kauffman Stadium',
#   'venue_address': '1 Royal Way, Kansas City, MO 64129, United States of America',
#   'venue_lat': 39.0514715,
#   'venue_lon': -94.48139730530374},
#  {'venue_id': 96,
#   'venue_name': 'LoanDepot Park',
#   'venue_address': 'Northwest 15th Avenue, Miami, FL 33128, United States of America',
#   'venue_lat': 25.778247399999998,
#   'venue_lon': -80.21980500744203},
#  {'venue_id': 97,
#   'venue_name': 'Minute Maid Park',
#   'venue_address': '501 Crawford Street, Houston, TX 77004, United States of America',
#   'venue_lat': 29.75723205,
#   'venue_lon': -95.35523391491142},
#  {'venue_id': 98,
#   'venue_name': 'Nationals Park',
#   'venue_address': '1500 South Capitol Street Southeast, Washington, DC 20590, United States of America',
#   'venue_lat': 38.87274095,
#   'venue_lon': -77.00838588569519},
#  {'venue_id': 99,
#   'venue_name': 'RingCentral Coliseum',
#   'venue_address': '7000 Coliseum Way, Oakland, CA 94621, United States of America',
#   'venue_lat': 37.751675000000006,
#   'venue_lon': -122.19937132239198},
#  {'venue_id': 100,
#   'venue_name': 'Oracle Park',
#   'venue_address': '24 Willie Mays Plaza, San Francisco, CA 94107, United States of America',
#   'venue_lat': 37.7786119,
#   'venue_lon': -122.39026745425639},
#  {'venue_id': 101,
#   'venue_name': 'Oriole Park',
#   'venue_address': '555 Russell Street, Baltimore, MD 21230, United States of America',
#   'venue_lat': 39.283982300000005,
#   'venue_lon': -76.62249149865416},
#  {'venue_id': 102,
#   'venue_name': 'Petco Park',
#   'venue_address': '100 Park Boulevard, San Diego, CA 92101, United States of America',
#   'venue_lat': 32.70718815,
#   'venue_lon': -117.15687730689476},
#  {'venue_id': 103,
#   'venue_name': 'PNC Park',
#   'venue_address': 'Federal Street, Pittsburgh, PA 15222, United States of America',
#   'venue_lat': 40.4469258,
#   'venue_lon': -80.00560626612204},
#  {'venue_id': 104,
#   'venue_name': 'Progressive Field',
#   'venue_address': '2401 Ontario Street, Cleveland, OH 44115, United States of America',
#   'venue_lat': 41.496090550000005,
#   'venue_lon': -81.68513191630367},
#  {'venue_id': 105,
#   'venue_name': 'Rogers Centre',
#   'venue_address': '1 Blue Jays Way, Old Toronto, ON M5V 1J1, Canada',
#   'venue_lat': 43.641659849999996,
#   'venue_lon': -79.38919761915824},
#  {'venue_id': 106,
#   'venue_name': 'T-Mobile Park',
#   'venue_address': 'South Royal Brougham Way, Seattle, WA 98104, United States of America',
#   'venue_lat': 47.59122645,
#   'venue_lon': -122.33256510340122},
#  {'venue_id': 107,
#   'venue_name': 'Target Field',
#   'venue_address': '1 Twins Way, Minneapolis, MN 55403, United States of America',
#   'venue_lat': 44.98168445,
#   'venue_lon': -93.27786434576453},
#  {'venue_id': 108,
#   'venue_name': 'Tropicana Field',
#   'venue_address': 'Pinellas Trail, Saint Petersburg, FL 33701, United States of America',
#   'venue_lat': 27.7680559,
#   'venue_lon': -82.65327550461797},
#  {'venue_id': 109,
#   'venue_name': 'Truist Park',
#   'venue_address': '755 Battery Avenue Southeast, The Battery Atlanta, GA 30339, United States of America',
#   'venue_lat': 33.89070855,
#   'venue_lon': -84.46853422885837},
#  {'venue_id': 110,
#   'venue_name': 'Wrigley Field',
#   'venue_address': '1060 West Addison Street, Chicago, IL 60613, United States of America',
#   'venue_lat': 41.94813535,
#   'venue_lon': -87.65635154722081},
#  {'venue_id': 111,
#   'venue_name': 'Yankee Stadium',
#   'venue_address': '1 East 161st Street, New York, NY 10451, United States of America',
#   'venue_lat': 40.82958275,
#   'venue_lon': -73.92652118491901},
#  {'venue_id': 112,
#   'venue_name': 'Allianz Field',
#   'venue_address': 'Simpson Street, Saint Paul, MN 55104, United States of America',
#   'venue_lat': 44.953139,
#   'venue_lon': -93.164687068773},
#  {'venue_id': 113,
#   'venue_name': 'Audi Field',
#   'venue_address': '100 Potomac Avenue Southwest, Washington, DC 20024, United States of America',
#   'venue_lat': 38.8682612,
#   'venue_lon': -77.01260516464751},
#  {'venue_id': 114,
#   'venue_name': 'BMO Stadium',
#   'venue_address': 'South Coliseum Drive, Los Angeles, CA 90037, United States of America',
#   'venue_lat': 34.012814,
#   'venue_lon': -118.28408924153342},
#  {'venue_id': 115,
#   'venue_name': 'BC Place',
#   'venue_address': '777 Pacific Boulevard, Vancouver, BC V6B, Canada',
#   'venue_lat': 49.2766905,
#   'venue_lon': -123.1120061895052},
#  {'venue_id': 116,
#   'venue_name': 'BMO Field',
#   'venue_address': "Princes' Boulevard, Old Toronto, ON M6K 3C3, Canada",
#   'venue_lat': 43.6333414,
#   'venue_lon': -79.41856141321526},
#  {'venue_id': 117,
#   'venue_name': "Children's Mercy Park",
#   'venue_address': 'Sporting Way, Kansas City, KS 66109, United States of America',
#   'venue_lat': 39.1216438,
#   'venue_lon': -94.82335037131475},
#  {'venue_id': 118,
#   'venue_name': "Dick's Sporting Goods Park",
#   'venue_address': '6000 Victory Way, Commerce City, CO 80022, United States of America',
#   'venue_lat': 39.8059455,
#   'venue_lon': -104.89192187416558},
#  {'venue_id': 119,
#   'venue_name': 'Dignity Health Sports Park Soccer Stadium',
#   'venue_address': '18400 South Avalon Boulevard, Carson, CA 90747, United States of America',
#   'venue_lat': 33.8642391,
#   'venue_lon': -118.26107952025521},
#  {'venue_id': 120,
#   'venue_name': 'DRV PNK Stadium',
#   'venue_address': 'Northwest 55th Street, Fort Lauderdale, FL 33309, United States of America',
#   'venue_lat': 26.1932625,
#   'venue_lon': -80.16066961287498},
#  {'venue_id': 121,
#   'venue_name': 'Barker Stadium',
#   'venue_address': 'Fairbanks Avenue, Winter Park, FL 32789, United States of America',
#   'venue_lat': 28.592762200000003,
#   'venue_lon': -81.34996401213354},
#  {'venue_id': 122,
#   'venue_name': 'Lower.com Field',
#   'venue_address': '96 Columbus Crew Way, Columbus, OH 43215, United States of America',
#   'venue_lat': 39.9683881,
#   'venue_lon': -83.0168287038446},
#  {'venue_id': 123,
#   'venue_name': 'PayPal Park',
#   'venue_address': '1123 Coleman Avenue, San Jose, CA 95110, United States of America',
#   'venue_lat': 37.35130865,
#   'venue_lon': -121.92467197349785},
#  {'venue_id': 124,
#   'venue_name': 'Shell Energy Stadium',
#   'venue_address': 'Walker Street, Houston, TX 77003, United States of America',
#   'venue_lat': 29.7520265,
#   'venue_lon': -95.35234094693865},
#  {'venue_id': 125,
#   'venue_name': 'Providence Park',
#   'venue_address': 'Southwest 18th Avenue, Portland, OR 97205, United States of America',
#   'venue_lat': 45.5214834,
#   'venue_lon': -122.6918430615391},
#  {'venue_id': 126,
#   'venue_name': 'North Building',
#   'venue_address': 'Calle Norte, Austin, TX 78758, United States of America',
#   'venue_lat': 30.38844835,
#   'venue_lon': -97.71988531133168},
#  {'venue_id': 127,
#   'venue_name': 'Red Bull Arena',
#   'venue_address': 'Cape May Street Northwest, Harrison, NJ 07029, United States of America',
#   'venue_lat': 40.736889700000006,
#   'venue_lon': -74.1495775012734},
#  {'venue_id': 128,
#   'venue_name': 'America First Field',
#   'venue_address': 'Rimando Way, Sandy, UT 84070, United States of America',
#   'venue_lat': 40.58295325,
#   'venue_lon': -111.89331198903758},
#  {'venue_id': 129,
#   'venue_name': 'Stade Saputo',
#   'venue_address': 'Rue Viau, Montreal, QC H1V 3J3, Canada',
#   'venue_lat': 45.5630905,
#   'venue_lon': -73.55264201236912},
#  {'venue_id': 130,
#   'venue_name': 'Subaru Park',
#   'venue_address': 'Seaport Drive, Chester, PA 19013, United States of America',
#   'venue_lat': 39.832909400000005,
#   'venue_lon': -75.37847387081464},
#  {'venue_id': 131,
#   'venue_name': 'Toyota Stadium',
#   'venue_address': '9200 World Cup Way, Frisco, TX 75034, United States of America',
#   'venue_lat': 33.1549042,
#   'venue_lon': -96.83526928863985},
#  {'venue_id': 132,
#   'venue_name': 'TQL Stadium',
#   'venue_address': 'Lowe Drive, Cincinnati, OH 45203, United States of America',
#   'venue_lat': 39.1114126,
#   'venue_lon': -84.52229446750526}]

# %%
# Flask Setup
#################################################
app = Flask(__name__)


#################################################
# Flask Routes
#################################################

@app.route("/api/venue")
def venue():
    # Create our session (link) from Python to the DB
    session = Session(engine)

    """Return a list of all venues"""
    # Query all venues
    results = session.query(Venue.venue_id, Venue.venue_name, Venue.venue_address, Venue.venue_lat, Venue.venue_lon).all()

    session.close()

    all_venues = []
    for result in results:
        venue_dict = {}
        venue_dict["venue_id"] = result[0]
        venue_dict["venue_name"] = result[1]
        venue_dict["venue_address"] = result[2]
        venue_dict["venue_lat"] = result[3]
        venue_dict["venue_lon"] = result[4]
        all_venues.append(venue_dict)

    return jsonify(all_venues)


@app.route("/api/teams")
def team():
    # Create our session (link) from Python to the DB
    session = Session(engine)

    """Return a list of all teams"""
    # Query all teams with league joined
    results = session.query(Team.team, Team.venue_id, League.league).filter(Team.league_id == League.league_id).all()

    session.close()

    all_teams = []
    for result in results:
        team_dict = {}
        team_dict["team_id"] = result[0]
        team_dict["venue_id"] = result[1]
        team_dict["league"] = result[2]

        all_teams.append(team_dict)

    return jsonify(all_teams)


if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with watchdog (fsevents)
# Traceback (most recent call last):
#   File "/Users/luke/opt/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py", line 15, in <module>
#     from ipykernel import kernelapp as app
#   File "/Users/luke/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 18, in <module>
#     from IPython.core.application import (
#   File "/Users/luke/opt/anaconda3/lib/python3.9/site-packages/IPython/__init__.py", line 53, in <module>
#     from .terminal.embed import embed
#   File "/Users/luke/opt/anaconda3/lib/python3.9/site-packages/IPython/terminal/embed.py", line 16, in <module>
#     from IPython.terminal.interactiveshell import TerminalInteractiveShell
#   File "/Users/luke/opt/anaconda3/lib/python3.9/site-packages/IPython/terminal/interactiveshell.py", line 48, in <module>
#     from .debugger import TerminalPdb, Pdb
#   File "/Users/luke/opt/anaconda3/lib/python3.9/site-packages/IPython/terminal/debugger.py", line 6, in <module>
#     from IPython.core.completer import IPCompleter
#   File "/Users/luke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/completer.py", line 250, in <module>
#     import jedi
#   File "/Users/luke/opt/anaconda3/lib/python3.9/site-packages/jedi/__init__.py", line 32, in <module>
#     from jedi.api import Script, Interpreter, set_debug_function, preload_module
#   File "/Users/luke/opt/anaconda3/lib/python3.9/site-packages/jedi/api/__init__.py", line 13, in <module>
#     import parso
#   File "/Users/luke/opt/anaconda3/lib/python3.9/site-packages/parso/__init__.py", line 42, in <module>
#     from parso.grammar import Grammar, load_grammar
#   File "/Users/luke/opt/anaconda3/lib/python3.9/site-packages/parso/grammar.py", line 13, in <module>
#     from parso.cache import parser_cache, load_module, try_to_save_module
#   File "/Users/luke/opt/anaconda3/lib/python3.9/site-packages/parso/cache.py", line 76, in <module>
#     _default_cache_path = _get_default_cache_path()
#   File "/Users/luke/opt/anaconda3/lib/python3.9/site-packages/parso/cache.py", line 73, in _get_default_cache_path
#     return dir_.expanduser()
# AttributeError: 'PosixPath' object has no attribute 'expanduser'
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /Users/luke/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3513: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
