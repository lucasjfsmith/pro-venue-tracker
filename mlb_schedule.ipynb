# %%
import pandas as pd

# %%
#read in csv
csv_file_path = "Resources/mlb-2023-UTC.csv"
mlb_df = pd.read_csv(csv_file_path)
mlb_df.head()
# Out:
#    Match Number  Round Number              Date         Location  \
# 0             1             1  30/03/2023 17:05   Nationals Park
# 1             2             1  30/03/2023 17:05   Yankee Stadium
# 2             3             1  30/03/2023 18:10      Fenway Park
# 3             4             1  30/03/2023 18:20    Wrigley Field
# 4             5             1  30/03/2023 19:10  Tropicana Field
#
#               Home Team             Away Team  Result
# 0  Washington Nationals        Atlanta Braves   2 - 7
# 1      New York Yankees  San Francisco Giants   5 - 0
# 2        Boston Red Sox     Baltimore Orioles  9 - 10
# 3          Chicago Cubs     Milwaukee Brewers   4 - 0
# 4        Tampa Bay Rays        Detroit Tigers   4 - 0

# %%
#Split date column into date and time
mlb_df[['Date', 'Time']] = mlb_df['Date'].str.split(pat=' ', n=1, expand=True)

mlb_df.head()
# Out:
#    Match Number  Round Number        Date         Location  \
# 0             1             1  30/03/2023   Nationals Park
# 1             2             1  30/03/2023   Yankee Stadium
# 2             3             1  30/03/2023      Fenway Park
# 3             4             1  30/03/2023    Wrigley Field
# 4             5             1  30/03/2023  Tropicana Field
#
#               Home Team             Away Team  Result   Time
# 0  Washington Nationals        Atlanta Braves   2 - 7  17:05
# 1      New York Yankees  San Francisco Giants   5 - 0  17:05
# 2        Boston Red Sox     Baltimore Orioles  9 - 10  18:10
# 3          Chicago Cubs     Milwaukee Brewers   4 - 0  18:20
# 4        Tampa Bay Rays        Detroit Tigers   4 - 0  19:10

# %%
#change date format
mlb_df['Date'] = pd.to_datetime(mlb_df['Date'], format='%d/%m/%Y')
mlb_df['Date'] = mlb_df['Date'].dt.strftime('%m/%d/%Y')
mlb_df.head()
# Out:
#    Match Number  Round Number        Date         Location  \
# 0             1             1  03/30/2023   Nationals Park
# 1             2             1  03/30/2023   Yankee Stadium
# 2             3             1  03/30/2023      Fenway Park
# 3             4             1  03/30/2023    Wrigley Field
# 4             5             1  03/30/2023  Tropicana Field
#
#               Home Team             Away Team  Result   Time
# 0  Washington Nationals        Atlanta Braves   2 - 7  17:05
# 1      New York Yankees  San Francisco Giants   5 - 0  17:05
# 2        Boston Red Sox     Baltimore Orioles  9 - 10  18:10
# 3          Chicago Cubs     Milwaukee Brewers   4 - 0  18:20
# 4        Tampa Bay Rays        Detroit Tigers   4 - 0  19:10

# %%
#changing time zone to central time zone (CST)
mlb_df['Time'] = pd.to_datetime(mlb_df['Time'], utc=True)
# Convert the time column to CST time zone
mlb_df['CST Gametime'] = mlb_df['Time'].dt.tz_convert('America/Chicago')

# Only show the time in 12 hr format
mlb_df['CST Gametime'] = mlb_df['CST Gametime'].apply(lambda x: x.strftime('%I:%M %p'))

# Print the DataFrame
mlb_df.head()
# Out:
#    Match Number  Round Number        Date         Location  \
# 0             1             1  03/30/2023   Nationals Park
# 1             2             1  03/30/2023   Yankee Stadium
# 2             3             1  03/30/2023      Fenway Park
# 3             4             1  03/30/2023    Wrigley Field
# 4             5             1  03/30/2023  Tropicana Field
#
#               Home Team             Away Team  Result  \
# 0  Washington Nationals        Atlanta Braves   2 - 7
# 1      New York Yankees  San Francisco Giants   5 - 0
# 2        Boston Red Sox     Baltimore Orioles  9 - 10
# 3          Chicago Cubs     Milwaukee Brewers   4 - 0
# 4        Tampa Bay Rays        Detroit Tigers   4 - 0
#
#                        Time CST Gametime
# 0 2023-08-07 17:05:00+00:00     12:05 PM
# 1 2023-08-07 17:05:00+00:00     12:05 PM
# 2 2023-08-07 18:10:00+00:00     01:10 PM
# 3 2023-08-07 18:20:00+00:00     01:20 PM
# 4 2023-08-07 19:10:00+00:00     02:10 PM

# %%
#Drop old time column
mlb_df = mlb_df.drop(columns=['Time'])
mlb_df.head()
# Out:
#    Match Number  Round Number        Date         Location  \
# 0             1             1  03/30/2023   Nationals Park
# 1             2             1  03/30/2023   Yankee Stadium
# 2             3             1  03/30/2023      Fenway Park
# 3             4             1  03/30/2023    Wrigley Field
# 4             5             1  03/30/2023  Tropicana Field
#
#               Home Team             Away Team  Result CST Gametime
# 0  Washington Nationals        Atlanta Braves   2 - 7     12:05 PM
# 1      New York Yankees  San Francisco Giants   5 - 0     12:05 PM
# 2        Boston Red Sox     Baltimore Orioles  9 - 10     01:10 PM
# 3          Chicago Cubs     Milwaukee Brewers   4 - 0     01:20 PM
# 4        Tampa Bay Rays        Detroit Tigers   4 - 0     02:10 PM

# %%
# Rename column
new_column_name = 'Week Number'
mlb_df.rename(columns={'Round Number': new_column_name}, inplace=True)
mlb_df.head()
# Out:
#    Match Number  Week Number        Date         Location  \
# 0             1            1  03/30/2023   Nationals Park
# 1             2            1  03/30/2023   Yankee Stadium
# 2             3            1  03/30/2023      Fenway Park
# 3             4            1  03/30/2023    Wrigley Field
# 4             5            1  03/30/2023  Tropicana Field
#
#               Home Team             Away Team  Result CST Gametime
# 0  Washington Nationals        Atlanta Braves   2 - 7     12:05 PM
# 1      New York Yankees  San Francisco Giants   5 - 0     12:05 PM
# 2        Boston Red Sox     Baltimore Orioles  9 - 10     01:10 PM
# 3          Chicago Cubs     Milwaukee Brewers   4 - 0     01:20 PM
# 4        Tampa Bay Rays        Detroit Tigers   4 - 0     02:10 PM

# %%
#drop Match Number column
mlb_df = mlb_df.drop(columns=["Match Number"])
mlb_df.head()
# Out:
#    Week Number        Date         Location             Home Team  \
# 0            1  03/30/2023   Nationals Park  Washington Nationals
# 1            1  03/30/2023   Yankee Stadium      New York Yankees
# 2            1  03/30/2023      Fenway Park        Boston Red Sox
# 3            1  03/30/2023    Wrigley Field          Chicago Cubs
# 4            1  03/30/2023  Tropicana Field        Tampa Bay Rays
#
#               Away Team  Result CST Gametime
# 0        Atlanta Braves   2 - 7     12:05 PM
# 1  San Francisco Giants   5 - 0     12:05 PM
# 2     Baltimore Orioles  9 - 10     01:10 PM
# 3     Milwaukee Brewers   4 - 0     01:20 PM
# 4        Detroit Tigers   4 - 0     02:10 PM

# %%
# Read in `team` csv so appropriate IDs can be added
team_df = pd.read_csv('Resources/team.csv')

# Take only mlb teams and reset index

mlb_teams_df = team_df[team_df['league_id'] == 4].reset_index()

mlb_teams_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      30 non-null     int64
#  1   team_id    30 non-null     int64
#  2   team       30 non-null     object
#  3   venue_id   30 non-null     int64
#  4   league_id  30 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.3+ KB

# %%
# Confirm all team names match with mlb_teams_df
team_nf = []

for i in range(len(mlb_df)):
    home_team = mlb_df.loc[i, 'Home Team']
    away_team = mlb_df.loc[i, 'Away Team']
    
    if home_team not in list(mlb_teams_df['team']):
        if home_team not in team_nf:
            print(f"{home_team} not found. Adding to tracker...")
            team_nf.append(home_team)
    
    if away_team not in list(mlb_teams_df['team']):
        if away_team not in team_nf:
            print(f"{away_team} not found. Adding to tracker...")
            team_nf.append(away_team)
            
print(team_nf)
# Out:
# []

# %%
# Assign each row a 'home_id', 'away_id', and 'venue_id'
mlb_df['home_id'] = ''
mlb_df['away_id'] = ''
mlb_df['venue_id'] = ''

for i in range(len(mlb_df)):
    home_team = mlb_teams_df[mlb_teams_df['team'] == mlb_df.loc[i, 'Home Team']]
    away_team = mlb_teams_df[mlb_teams_df['team'] == mlb_df.loc[i, 'Away Team']]
    
    mlb_df.loc[i, 'home_id'] = int(home_team['team_id'])
    mlb_df.loc[i, 'venue_id'] = int(home_team['venue_id'])
    mlb_df.loc[i, 'away_id'] = int(away_team['team_id'])

mlb_df
# Out:
#       Week Number        Date               Location             Home Team  \
# 0               1  03/30/2023         Nationals Park  Washington Nationals
# 1               1  03/30/2023         Yankee Stadium      New York Yankees
# 2               1  03/30/2023            Fenway Park        Boston Red Sox
# 3               1  03/30/2023          Wrigley Field          Chicago Cubs
# 4               1  03/30/2023        Tropicana Field        Tampa Bay Rays
# ...           ...         ...                    ...                   ...
# 2425           27  10/01/2023             Citi Field         New York Mets
# 2426           27  10/01/2023  Guaranteed Rate Field     Chicago White Sox
# 2427           27  10/01/2023       Kauffman Stadium    Kansas City Royals
# 2428           27  10/01/2023  American Family Field     Milwaukee Brewers
# 2429           27  10/01/2023          Busch Stadium   St. Louis Cardinals
#
#                   Away Team  Result CST Gametime home_id away_id venue_id
# 0            Atlanta Braves   2 - 7     12:05 PM     111     122       98
# 1      San Francisco Giants   5 - 0     12:05 PM     124     113      111
# 2         Baltimore Orioles  9 - 10     01:10 PM     104     114       91
# 3         Milwaukee Brewers   4 - 0     01:20 PM     123      95      110
# 4            Detroit Tigers   4 - 0     02:10 PM     121     101      108
# ...                     ...     ...          ...     ...     ...      ...
# 2425  Philadelphia Phillies     NaN     02:10 PM      99     100       86
# 2426       San Diego Padres     NaN     02:10 PM     107     115       94
# 2427       New York Yankees     NaN     02:10 PM     108     124       95
# 2428           Chicago Cubs     NaN     02:10 PM      95     123       82
# 2429        Cincinnati Reds     NaN     02:15 PM      97     106       84
#
# [2430 rows x 10 columns]

# %%
mlb_formatted_df = mlb_df[["Date", "CST Gametime", "home_id", "away_id", "venue_id"]]
mlb_formatted_df = mlb_formatted_df.rename(columns={"Date":"event_date",
                                                   "CST Gametime": "event_time_cst"})
mlb_formatted_df.head()
# Out:
#    event_date event_time_cst home_id away_id venue_id
# 0  03/30/2023       12:05 PM     111     122       98
# 1  03/30/2023       12:05 PM     124     113      111
# 2  03/30/2023       01:10 PM     104     114       91
# 3  03/30/2023       01:20 PM     123      95      110
# 4  03/30/2023       02:10 PM     121     101      108
