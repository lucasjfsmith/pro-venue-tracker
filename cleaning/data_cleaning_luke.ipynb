# %%
import requests
import pandas as pd
import os

from api_key import geoapify_key

# %%
# Create stadium_df
stadiums_path = os.path.join("..", "Resources", "stadiums.csv")
stadium_df = pd.read_csv(stadiums_path)

# add a team_id column
stadium_df["team_id"] = list(range(1, (len(stadium_df)+1)))
stadium_df = stadium_df[["team_id", "Team", "League", "Division", "Lat", "Long"]]
stadium_df
# Out:
#      team_id               Team League            Division        Lat  \
# 0          1   Dallas Mavericks    NBA                West  32.790556
# 1          2      Orlando Magic    NBA                East  28.539167
# 2          3  San Antonio Spurs    NBA                West  29.426944
# 3          4     Denver Nuggets    NBA                West  39.748920
# 4          5      Brooklyn Nets    NBA                East  40.682661
# ..       ...                ...    ...                 ...        ...
# 148      149          FC Dallas    MLS  Western Conference  33.154444
# 149      150      FC Cincinnati    MLS  Eastern Conference  39.111389
# 150      151   New York City FC    MLS  Eastern Conference  40.829167
# 151      152       Charlotte FC    MLS  Eastern Conference  35.225833
# 152      153  St. Louis City SC    MLS  Eastern Conference  38.631200
#
#            Long
# 0    -96.810278
# 1    -81.383611
# 2    -98.437500
# 3   -105.008400
# 4    -73.975225
# ..          ...
# 148  -96.835278
# 149  -84.522222
# 150  -73.926389
# 151  -80.852778
# 152  -90.210500
#
# [153 rows x 6 columns]

# %%
# Create league_df from the unique leagues in stadium_df
league_ids = list(range(1,6))

league_df = pd.DataFrame({
    "league_id": league_ids,
    "league": stadium_df["League"].unique()
})

# Export league_df
league_df.to_csv(os.path.join("..", "Resources", "league.csv"), index=False)
league_df
# Out:
#    league_id league
# 0          1    NBA
# 1          2    NFL
# 2          3    NHL
# 3          4    MLB
# 4          5    MLS

# %%
# Add league_id to each row of stadium_df
stadium_df["league_id"] = ""
for index, row in stadium_df.iterrows():
    if row["League"] == "NBA":
        stadium_df.loc[index,"league_id"] = 1
    elif row["League"] == "NFL":
        stadium_df.loc[index,"league_id"] = 2
    elif row["League"] == "NHL":
        stadium_df.loc[index,"league_id"] = 3
    elif row["League"] == "MLB":
        stadium_df.loc[index,"league_id"] = 4
    elif row["League"] == "MLS":
        stadium_df.loc[index,"league_id"] = 5

## Drop League and Division columns
stadium_df = stadium_df[['team_id', 'Team', 'Lat', 'Long', 'league_id']]
stadium_df.head()
# Out:
#    team_id               Team        Lat        Long league_id
# 0        1   Dallas Mavericks  32.790556  -96.810278         1
# 1        2      Orlando Magic  28.539167  -81.383611         1
# 2        3  San Antonio Spurs  29.426944  -98.437500         1
# 3        4     Denver Nuggets  39.748920 -105.008400         1
# 4        5      Brooklyn Nets  40.682661  -73.975225         1

# %%
# Create venue_df

# Set up constants for API call
base_url = "https://api.geoapify.com/v2/places"
params = {
    "apiKey": geoapify_key,
    "categories": "sport.stadium"
}

venue_id_dict = {}
current_venue_id = 1

# Iterate through stadium_df and stadium data for each team
for index, row in stadium_df.iterrows():
    # set lon and lat variable
    lon = row['Long']
    lat = row['Lat']
    
    # update params dict
    params["bias"] = f"proximity:{lon},{lat}"
    
    # API call
    response_features = requests.get(base_url, params=params).json()['features']
    
    # make sure data was returned
    if len(response_features) > 0:
        
        # grab the first feature that has a 'name' property
        for feature in response_features:
            if "name" in feature['properties'].keys():
                stadium = feature['properties']
                break
        
        # add venue to venue_id_dict if not already there
        if stadium["name"] not in venue_id_dict.keys():
            venue_id_dict[stadium["name"]] = current_venue_id
            current_venue_id +=1
        
        # add data to stadium_df
        stadium_df.loc[index, "venue_id"] = venue_id_dict[stadium["name"]]
        stadium_df.loc[index, "Venue Name"] = stadium['name']
        if "city" in stadium.keys():
            stadium_df.loc[index, "Venue City"] = stadium['city']
        if "state" in stadium.keys():
            stadium_df.loc[index, "Venue State"] = stadium['state']
        if "country_code" in stadium.keys():
            stadium_df.loc[index, "Venue Country"] = stadium['country_code']
        if "address_line2" in stadium.keys():
            stadium_df.loc[index, "Venue Address"] = stadium['address_line2']
        stadium_df.loc[index, "Venue Lat"]= stadium['lat']
        stadium_df.loc[index, "Venue Lon"]= stadium['lon']
        if "capacity" in stadium['datasource']['raw'].keys():
            capacity = stadium['datasource']['raw']['capacity']
            if type(capacity) == str:
                stadium_df.loc[index, "Venue Capacity"] = int(capacity.replace(",","").replace(".",""))
            else:
                stadium_df.loc[index, "Venue Capacity"] = capacity
        print(f"New stadium added: {stadium['name']}")
    else:
        print("NO RESULTS:" + stadium_df.loc[index,"Team"])
# Out:
# /var/folders/x5/9msd5vy917xg5khrc19tx5p80000gn/T/ipykernel_36440/2530796516.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stadium_df.loc[index, "venue_id"] = venue_id_dict[stadium["name"]]
# New stadium added: American Airlines Center
# New stadium added: Amway Center
# New stadium added: AT&T Center
# New stadium added: Ball Arena
# New stadium added: Barclays Center
# New stadium added: Capital One Arena
# New stadium added: Chase Center
# New stadium added: Crypto.com Arena
# New stadium added: Crypto.com Arena
# New stadium added: FedExForum
# New stadium added: Fiserv Forum
# New stadium added: Footprint Center
# New stadium added: Kaseya Center
# New stadium added: Gainbridge Fieldhouse
# New stadium added: Golden 1 Center
# New stadium added: Little Caesars Arena
# New stadium added: Madison Square Garden
# New stadium added: Moda Center
# New stadium added: Paycom Center
# New stadium added: Rocket Mortgage FieldHouse
# New stadium added: Scotiabank Arena
# New stadium added: Smoothie King Center
# New stadium added: Spectrum Center
# New stadium added: State Farm Arena
# New stadium added: Target Center
# New stadium added: TD Garden
# New stadium added: Toyota Center
# New stadium added: United Center
# New stadium added: Vivint Arena
# New stadium added: Wells Fargo Center
# New stadium added: Allegiant Stadium
# New stadium added: Arrowhead Stadium
# New stadium added: AT&T Stadium
# New stadium added: Bank of America Stadium
# New stadium added: Caesar's Superdome
# New stadium added: Empower Field
# New stadium added: FedExField
# New stadium added: Cleveland Browns Stadium
# New stadium added: Ford Field
# New stadium added: Gillette Stadium
# New stadium added: Hard Rock Stadium
# New stadium added: Acrisure Stadium
# New stadium added: Highmark Blue Cross Blue Shield Stadium
# New stadium added: Lambeau Field
# New stadium added: Levi’s Stadium
# New stadium added: Lincoln Financial Field
# New stadium added: Lucas Oil Stadium
# New stadium added: Lumen Field
# New stadium added: M&T Bank Stadium
# New stadium added: Mercedes-Benz Stadium
# New stadium added: MetLife Stadium
# New stadium added: MetLife Stadium
# New stadium added: Nissan Stadium
# New stadium added: NRG Stadium
# New stadium added: Paycor Stadium
# New stadium added: Raymond James Stadium
# New stadium added: SoFi Stadium
# New stadium added: SoFi Stadium
# New stadium added: Soldier Field
# New stadium added: State Farm Stadium
# New stadium added: TIAA Bank Field
# New stadium added: US Bank Stadium
# New stadium added: Amalie Arena
# New stadium added: American Airlines Center
# New stadium added: Ball Arena
# New stadium added: Centre Bell
# New stadium added: Bridgestone Arena
# New stadium added: Canada Life Centre
# New stadium added: Canadian Tire Centre
# New stadium added: Capital One Arena
# New stadium added: Climate Pledge Arena
# New stadium added: Crypto.com Arena
# New stadium added: Enterprise Center
# New stadium added: FLA Live Arena
# New stadium added: Gila River Arena
# New stadium added: Honda Center
# New stadium added: KeyBank Center
# New stadium added: Little Caesars Arena
# New stadium added: Madison Square Garden
# New stadium added: Nationwide Arena
# New stadium added: Carter-Finley Stadium
# New stadium added: PPG Paints Arena
# New stadium added: Prudential Center
# New stadium added: Rogers Arena
# New stadium added: Rogers Place
# New stadium added: SAP Center at San Jose
# New stadium added: Scotiabank Arena
# New stadium added: Scotiabank Saddledome
# New stadium added: TD Garden
# New stadium added: T-Mobile Arena
# New stadium added: UBS Arena
# New stadium added: United Center
# New stadium added: Wells Fargo Center
# New stadium added: Xcel Energy Center
# New stadium added: American Family Field
# New stadium added: Angel Stadium of Anaheim
# New stadium added: Busch Stadium
# New stadium added: Chase Field
# New stadium added: Citi Field
# New stadium added: Citizens Bank Park
# New stadium added: Comerica Park
# New stadium added: Coors Field
# New stadium added: Dodger Stadium
# New stadium added: Fenway Park
# New stadium added: Globe Life Field
# New stadium added: Great American Ball Park
# New stadium added: Guaranteed Rate Field
# New stadium added: Kauffman Stadium
# New stadium added: LoanDepot Park
# New stadium added: Minute Maid Park
# New stadium added: Nationals Park
# New stadium added: RingCentral Coliseum
# New stadium added: Oracle Park
# New stadium added: Oriole Park at Camden Yards
# New stadium added: Petco Park
# New stadium added: PNC Park
# New stadium added: Progressive Field
# New stadium added: Rogers Centre
# New stadium added: T-Mobile Park
# New stadium added: Target Field
# New stadium added: Tropicana Field
# New stadium added: Truist Park
# New stadium added: Wrigley Field
# New stadium added: Yankee Stadium
# New stadium added: Allianz Field
# New stadium added: Audi Field
# New stadium added: BMO Stadium
# New stadium added: BC Place
# New stadium added: BMO Field
# New stadium added: Children's Mercy Park
# New stadium added: Dick's Sporting Goods Park
# New stadium added: Dignity Health Sports Park Soccer Stadium
# New stadium added: DRV PNK Stadium
# New stadium added: Barker Stadium
# New stadium added: Gillette Stadium
# New stadium added: Lower.com Field
# New stadium added: Lumen Field
# New stadium added: Mercedes-Benz Stadium
# New stadium added: Nissan Stadium
# New stadium added: PayPal Park
# New stadium added: Shell Energy Stadium
# New stadium added: Providence Park
# New stadium added: North Building
# New stadium added: Red Bull Arena
# New stadium added: America First Field
# New stadium added: Stade Saputo
# New stadium added: Soldier Field
# New stadium added: Subaru Park
# New stadium added: Toyota Stadium
# New stadium added: TQL Stadium
# New stadium added: Yankee Stadium
# New stadium added: Bank of America Stadium
# New stadium added: CityPark

# %%
stadium_df['venue_id'] = stadium_df['venue_id'].astype(int)
stadium_df.head()
# Out:
#    team_id               Team        Lat        Long league_id  venue_id  \
# 0        1   Dallas Mavericks  32.790556  -96.810278         1         1
# 1        2      Orlando Magic  28.539167  -81.383611         1         2
# 2        3  San Antonio Spurs  29.426944  -98.437500         1         3
# 3        4     Denver Nuggets  39.748920 -105.008400         1         4
# 4        5      Brooklyn Nets  40.682661  -73.975225         1         5
#
#                  Venue Name   Venue City Venue State Venue Country  \
# 0  American Airlines Center       Dallas       Texas            us
# 1              Amway Center      Orlando     Florida            us
# 2               AT&T Center  San Antonio       Texas            us
# 3                Ball Arena       Denver    Colorado            us
# 4           Barclays Center     New York    New York            us
#
#                                        Venue Address  Venue Lat   Venue Lon  \
# 0  2500 Victory Avenue, Dallas, TX 75219, United ...  32.790508  -96.810272
# 1  Hughey Avenue, Orlando, FL 32801, United State...  28.539274  -81.384007
# 2    San Antonio, TX 78219, United States of America  29.427050  -98.437507
# 3  1000 Chopper Circle, Denver, CO 80204, United ...  39.748684 -105.007544
# 4  620 Atlantic Avenue, New York, NY 11217, Unite...  40.682511  -73.975252
#
#    Venue Capacity
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
# Split the stadium_df into team_df and venue_df
venue_cols = ["venue_id", "Venue Name", "Venue City", "Venue State", "Venue Country", "Venue Address", "Venue Lat", "Venue Lon", "Venue Capacity"]
venue_df = stadium_df[venue_cols]
venue_col_names = {
    "Venue Name":"venue_name",
    "Venue City":"venue_city",
    "Venue State":"venue_state",
    "Venue Country":"venue_country",
    "Venue Address":"venue_address",
    "Venue Lat":"venue_lat",
    "Venue Lon":"venue_lon",
    "Venue Capacity":"venue_capacity"
}
venue_df = venue_df.rename(columns=venue_col_names)

# Place holder column
venue_df['next_event_id'] = 0

# Drop duplicates from Venue
venue_df = venue_df.drop_duplicates()

venue_df.head()
# Out:
#    venue_id                venue_name   venue_city venue_state venue_country  \
# 0         1  American Airlines Center       Dallas       Texas            us
# 1         2              Amway Center      Orlando     Florida            us
# 2         3               AT&T Center  San Antonio       Texas            us
# 3         4                Ball Arena       Denver    Colorado            us
# 4         5           Barclays Center     New York    New York            us
#
#                                        venue_address  venue_lat   venue_lon  \
# 0  2500 Victory Avenue, Dallas, TX 75219, United ...  32.790508  -96.810272
# 1  Hughey Avenue, Orlando, FL 32801, United State...  28.539274  -81.384007
# 2    San Antonio, TX 78219, United States of America  29.427050  -98.437507
# 3  1000 Chopper Circle, Denver, CO 80204, United ...  39.748684 -105.007544
# 4  620 Atlantic Avenue, New York, NY 11217, Unite...  40.682511  -73.975252
#
#    venue_capacity  next_event_id
# 0             NaN              0
# 1             NaN              0
# 2             NaN              0
# 3             NaN              0
# 4             NaN              0

# %%
team_df = stadium_df[["team_id", "Team", "venue_id", "league_id"]]
team_df["league_id"] = team_df["league_id"].astype(int)

team_df = team_df.rename(columns={
    "Team":"team"
})

team_df.head()
# Out:
# /var/folders/x5/9msd5vy917xg5khrc19tx5p80000gn/T/ipykernel_36440/824156743.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df["league_id"] = team_df["league_id"].astype(int)
#    team_id               team  venue_id  league_id
# 0        1   Dallas Mavericks         1          1
# 1        2      Orlando Magic         2          1
# 2        3  San Antonio Spurs         3          1
# 3        4     Denver Nuggets         4          1
# 4        5      Brooklyn Nets         5          1

# %%
# Austin FC Venue
venue_df[venue_df["venue_name"] == "North Building"]
venue_df.loc[142, 'venue_name'] = "Q2 Stadium"

# %%
venue_df.to_csv(os.path.join("..", "Resources", "venue.csv"), index=False)
team_df.to_csv(os.path.join("..", "Resources", "team.csv"), index=False)
