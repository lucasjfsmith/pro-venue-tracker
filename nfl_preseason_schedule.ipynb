# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_html('https://www.pro-football-reference.com/years/2023/preseason.htm')

# %%
nfl_pre_df = df[1]
nfl_pre_df = nfl_pre_df.drop(columns='Unnamed: 5')
nfl_pre_df = nfl_pre_df.rename(columns={"Unnamed: 2":"DOM",
                                        "Pts":"VisPts",
                                        "Pts.1":"HomePts"})
nfl_pre_df
# Out:
#     Week  Day        DOM                  VisTm  VisPts  \
# 0    NaN  Thu   August 3          New York Jets      16
# 1    1.0  Thu  August 10         Houston Texans       0
# 2    1.0  Thu  August 10      Minnesota Vikings       0
# 3    1.0  Fri  August 11      Green Bay Packers       0
# 4    1.0  Fri  August 11  Washington Commanders       0
# 5    1.0  Fri  August 11         Denver Broncos       0
# 6    1.0  Fri  August 11        New York Giants       0
# 7    1.0  Fri  August 11        Atlanta Falcons       0
# 8    1.0  Fri  August 11    Pittsburgh Steelers       0
# 9    1.0  Sat  August 12   Los Angeles Chargers       0
# 10   1.0  Sat  August 12    Philadelphia Eagles       0
# 11   1.0  Sat  August 12   Jacksonville Jaguars       0
# 12   1.0  Sat  August 12       Tennessee Titans       0
# 13   1.0  Sat  August 12          New York Jets       0
# 14   1.0  Sat  August 12     Indianapolis Colts       0
# 15   1.0  Sun  August 13     Kansas City Chiefs       0
# 16   1.0  Sun  August 13    San Francisco 49ers       0
# 17   2.0  Thu  August 17       Cleveland Browns       0
# 18   2.0  Fri  August 18     Cincinnati Bengals       0
# 19   2.0  Fri  August 18      Carolina Panthers       0
# 20   2.0  Sat  August 19         Miami Dolphins       0
# 21   2.0  Sat  August 19         Denver Broncos       0
# 22   2.0  Sat  August 19         Dallas Cowboys       0
# 23   2.0  Sat  August 19      Las Vegas Raiders       0
# 24   2.0  Sat  August 19          Buffalo Bills       0
# 25   2.0  Sat  August 19   Tampa Bay Buccaneers       0
# 26   2.0  Sat  August 19   New England Patriots       0
# 27   2.0  Sat  August 19   Jacksonville Jaguars       0
# 28   2.0  Sat  August 19     Kansas City Chiefs       0
# 29   2.0  Sat  August 19          Chicago Bears       0
# 30   2.0  Sat  August 19       Tennessee Titans       0
# 31   2.0  Sun  August 20     New Orleans Saints       0
# 32   2.0  Mon  August 21       Baltimore Ravens       0
# 33   3.0  Thu  August 24    Pittsburgh Steelers       0
# 34   3.0  Thu  August 24     Indianapolis Colts       0
# 35   3.0  Fri  August 25   Los Angeles Chargers       0
# 36   3.0  Fri  August 25   New England Patriots       0
# 37   3.0  Fri  August 25          Detroit Lions       0
# 38   3.0  Sat  August 26          Buffalo Bills       0
# 39   3.0  Sat  August 26      Las Vegas Raiders       0
# 40   3.0  Sat  August 26       Los Angeles Rams       0
# 41   3.0  Sat  August 26       Seattle Seahawks       0
# 42   3.0  Sat  August 26         Miami Dolphins       0
# 43   3.0  Sat  August 26       Cleveland Browns       0
# 44   3.0  Sat  August 26      Arizona Cardinals       0
# 45   3.0  Sat  August 26          New York Jets       0
# 46   3.0  Sat  August 26       Baltimore Ravens       0
# 47   3.0  Sat  August 26     Cincinnati Bengals       0
# 48   3.0  Sun  August 27         Houston Texans       0
#
#                    HomeTm  HomePts
# 0        Cleveland Browns       21
# 1    New England Patriots        0
# 2        Seattle Seahawks        0
# 3      Cincinnati Bengals        0
# 4        Cleveland Browns        0
# 5       Arizona Cardinals        0
# 6           Detroit Lions        0
# 7          Miami Dolphins        0
# 8    Tampa Bay Buccaneers        0
# 9        Los Angeles Rams        0
# 10       Baltimore Ravens        0
# 11         Dallas Cowboys        0
# 12          Chicago Bears        0
# 13      Carolina Panthers        0
# 14          Buffalo Bills        0
# 15     New Orleans Saints        0
# 16      Las Vegas Raiders        0
# 17    Philadelphia Eagles        0
# 18        Atlanta Falcons        0
# 19        New York Giants        0
# 20         Houston Texans        0
# 21    San Francisco 49ers        0
# 22       Seattle Seahawks        0
# 23       Los Angeles Rams        0
# 24    Pittsburgh Steelers        0
# 25          New York Jets        0
# 26      Green Bay Packers        0
# 27          Detroit Lions        0
# 28      Arizona Cardinals        0
# 29     Indianapolis Colts        0
# 30      Minnesota Vikings        0
# 31   Los Angeles Chargers        0
# 32  Washington Commanders        0
# 33        Atlanta Falcons        0
# 34    Philadelphia Eagles        0
# 35    San Francisco 49ers        0
# 36       Tennessee Titans        0
# 37      Carolina Panthers        0
# 38          Chicago Bears        0
# 39         Dallas Cowboys        0
# 40         Denver Broncos        0
# 41      Green Bay Packers        0
# 42   Jacksonville Jaguars        0
# 43     Kansas City Chiefs        0
# 44      Minnesota Vikings        0
# 45        New York Giants        0
# 46   Tampa Bay Buccaneers        0
# 47  Washington Commanders        0
# 48     New Orleans Saints        0

# %%
# Create date string from Day and Date columns
nfl_pre_df['Date'] = ""

for i in range(len(nfl_pre_df)):
    month_day = nfl_pre_df.loc[i, "DOM"].split(" ")
    month = dt.datetime.strptime(month_day[0], '%B').month
    day = int(month_day[1])
    date = dt.date(2023,month,day).strftime('%m/%d/%Y')
    
    nfl_pre_df.loc[i, 'Date'] = date

# %%
nfl_pre_df = nfl_pre_df.drop(columns=['DOM','Week','Day','VisPts','HomePts'])
nfl_pre_df.head()
# Out:
#                    VisTm                HomeTm        Date
# 0          New York Jets      Cleveland Browns  08/03/2023
# 1         Houston Texans  New England Patriots  08/10/2023
# 2      Minnesota Vikings      Seattle Seahawks  08/10/2023
# 3      Green Bay Packers    Cincinnati Bengals  08/11/2023
# 4  Washington Commanders      Cleveland Browns  08/11/2023

# %%
team_df = pd.read_csv('Resources/team.csv')

# Take only nfl teams and reset index

nfl_teams_df = team_df[team_df['league_id'] == 2].reset_index()

nfl_teams_df.head()
# Out:
#    index  team_id                team  venue_id  league_id
# 0     30       31   Las Vegas Raiders        30          2
# 1     31       32  Kansas City Chiefs        31          2
# 2     32       33      Dallas Cowboys        32          2
# 3     33       34   Carolina Panthers        33          2
# 4     34       35  New Orleans Saints        34          2

# %%
# Confirm all team names match with mlb_teams_df
team_nf = []

for i in range(len(nfl_pre_df)):
    home_team = nfl_pre_df.loc[i, 'HomeTm']
    away_team = nfl_pre_df.loc[i, 'VisTm']
    
    if home_team not in list(nfl_teams_df['team']):
        if home_team not in team_nf:
            print(f"{home_team} not found. Adding to tracker...")
            team_nf.append(home_team)
    
    if away_team not in list(nfl_teams_df['team']):
        if away_team not in team_nf:
            print(f"{away_team} not found. Adding to tracker...")
            team_nf.append(away_team)
            
print(team_nf)
# Out:
# []

# %%
# Assign each row a 'home_id', 'away_id', and 'venue_id'
nfl_pre_df['home_id'] = ''
nfl_pre_df['away_id'] = ''
nfl_pre_df['venue_id'] = ''

for i in range(len(nfl_pre_df)):
    home_team = nfl_teams_df[nfl_teams_df['team'] == nfl_pre_df.loc[i, 'HomeTm']]
    away_team = nfl_teams_df[nfl_teams_df['team'] == nfl_pre_df.loc[i, 'VisTm']]
    
    nfl_pre_df.loc[i, 'home_id'] = int(home_team['team_id'])
    nfl_pre_df.loc[i, 'venue_id'] = int(home_team['venue_id'])
    nfl_pre_df.loc[i, 'away_id'] = int(away_team['team_id'])

nfl_pre_df
# Out:
#                     VisTm                 HomeTm        Date home_id away_id  \
# 0           New York Jets       Cleveland Browns  08/03/2023      38      52
# 1          Houston Texans   New England Patriots  08/10/2023      40      54
# 2       Minnesota Vikings       Seattle Seahawks  08/10/2023      48      62
# 3       Green Bay Packers     Cincinnati Bengals  08/11/2023      55      44
# 4   Washington Commanders       Cleveland Browns  08/11/2023      38      37
# 5          Denver Broncos      Arizona Cardinals  08/11/2023      60      36
# 6         New York Giants          Detroit Lions  08/11/2023      39      51
# 7         Atlanta Falcons         Miami Dolphins  08/11/2023      41      50
# 8     Pittsburgh Steelers   Tampa Bay Buccaneers  08/11/2023      56      42
# 9    Los Angeles Chargers       Los Angeles Rams  08/12/2023      57      58
# 10    Philadelphia Eagles       Baltimore Ravens  08/12/2023      49      46
# 11   Jacksonville Jaguars         Dallas Cowboys  08/12/2023      33      61
# 12       Tennessee Titans          Chicago Bears  08/12/2023      59      53
# 13          New York Jets      Carolina Panthers  08/12/2023      34      52
# 14     Indianapolis Colts          Buffalo Bills  08/12/2023      43      47
# 15     Kansas City Chiefs     New Orleans Saints  08/13/2023      35      32
# 16    San Francisco 49ers      Las Vegas Raiders  08/13/2023      31      45
# 17       Cleveland Browns    Philadelphia Eagles  08/17/2023      46      38
# 18     Cincinnati Bengals        Atlanta Falcons  08/18/2023      50      55
# 19      Carolina Panthers        New York Giants  08/18/2023      51      34
# 20         Miami Dolphins         Houston Texans  08/19/2023      54      41
# 21         Denver Broncos    San Francisco 49ers  08/19/2023      45      36
# 22         Dallas Cowboys       Seattle Seahawks  08/19/2023      48      33
# 23      Las Vegas Raiders       Los Angeles Rams  08/19/2023      57      31
# 24          Buffalo Bills    Pittsburgh Steelers  08/19/2023      42      43
# 25   Tampa Bay Buccaneers          New York Jets  08/19/2023      52      56
# 26   New England Patriots      Green Bay Packers  08/19/2023      44      40
# 27   Jacksonville Jaguars          Detroit Lions  08/19/2023      39      61
# 28     Kansas City Chiefs      Arizona Cardinals  08/19/2023      60      32
# 29          Chicago Bears     Indianapolis Colts  08/19/2023      47      59
# 30       Tennessee Titans      Minnesota Vikings  08/19/2023      62      53
# 31     New Orleans Saints   Los Angeles Chargers  08/20/2023      58      35
# 32       Baltimore Ravens  Washington Commanders  08/21/2023      37      49
# 33    Pittsburgh Steelers        Atlanta Falcons  08/24/2023      50      42
# 34     Indianapolis Colts    Philadelphia Eagles  08/24/2023      46      47
# 35   Los Angeles Chargers    San Francisco 49ers  08/25/2023      45      58
# 36   New England Patriots       Tennessee Titans  08/25/2023      53      40
# 37          Detroit Lions      Carolina Panthers  08/25/2023      34      39
# 38          Buffalo Bills          Chicago Bears  08/26/2023      59      43
# 39      Las Vegas Raiders         Dallas Cowboys  08/26/2023      33      31
# 40       Los Angeles Rams         Denver Broncos  08/26/2023      36      57
# 41       Seattle Seahawks      Green Bay Packers  08/26/2023      44      48
# 42         Miami Dolphins   Jacksonville Jaguars  08/26/2023      61      41
# 43       Cleveland Browns     Kansas City Chiefs  08/26/2023      32      38
# 44      Arizona Cardinals      Minnesota Vikings  08/26/2023      62      60
# 45          New York Jets        New York Giants  08/26/2023      51      52
# 46       Baltimore Ravens   Tampa Bay Buccaneers  08/26/2023      56      49
# 47     Cincinnati Bengals  Washington Commanders  08/26/2023      37      55
# 48         Houston Texans     New Orleans Saints  08/27/2023      35      54
#
#    venue_id
# 0        37
# 1        39
# 2        47
# 3        53
# 4        37
# 5        57
# 6        38
# 7        40
# 8        54
# 9        55
# 10       48
# 11       32
# 12       56
# 13       33
# 14       42
# 15       34
# 16       30
# 17       45
# 18       49
# 19       50
# 20       52
# 21       44
# 22       47
# 23       55
# 24       41
# 25       50
# 26       43
# 27       38
# 28       57
# 29       46
# 30       59
# 31       55
# 32       36
# 33       49
# 34       45
# 35       44
# 36       51
# 37       33
# 38       56
# 39       32
# 40       35
# 41       43
# 42       58
# 43       31
# 44       59
# 45       50
# 46       54
# 47       36
# 48       34

# %%
nfl_pre_df["CST Gametime"] = "6:00 PM"
nfl_pre_formatted_df = nfl_pre_df[["Date", "CST Gametime", "home_id", "away_id", "venue_id"]]
nfl_pre_formatted_df = nfl_pre_formatted_df.rename(columns={"Date":"event_date",
                                                   "CST Gametime": "event_time_cst"})
nfl_pre_formatted_df.head()
# Out:
#    event_date event_time_cst home_id away_id venue_id
# 0  08/03/2023        6:00 PM      38      52       37
# 1  08/10/2023        6:00 PM      40      54       39
# 2  08/10/2023        6:00 PM      48      62       47
# 3  08/11/2023        6:00 PM      55      44       53
# 4  08/11/2023        6:00 PM      38      37       37

# %%
nfl_pre_formatted_df.to_csv("Resources/events/nfl_pre_events.csv")
