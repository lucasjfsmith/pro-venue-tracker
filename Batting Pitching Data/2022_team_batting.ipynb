# %%
import pandas as pd
from time import sleep

# %%
# Create a list of all mlb team abbreviations used by Baseball-Reference
team_abr = list(pd.read_csv("mlb_teams.csv")["Abbreviation"])

# %%
url_1 = "https://www.baseball-reference.com/teams/tgl.cgi?team="
url_2 = "&t=b&year=2022"
batting_dfs = []

for team in team_abr:
    print(team)
    url = f"{url_1}{team}{url_2}"
    team_df = pd.read_html(url)[0]
    
    for i in range(len(team_df)):
        # Convert 'Gtm' to int
        try:
            int(team_df.loc[i, "Gtm"])
        except:
            team_df = team_df.drop(i)

    # Update data types    
    team_df['Gtm'] = team_df['Gtm'].astype(int)
    team_df['HR'] = team_df['HR'].astype(int)

    # Reset index after rows dropped and add a 'Team column'
    team_df = team_df.reset_index(drop=True)
    team_df['Team'] = team
        
    for i in range(len(team_df)):
        
        # Add 'Target HR' column
        if i != len(team_df) - 1:
            next_i = i+1
            if int(team_df.loc[next_i, 'HR']) > 0:
                team_df.loc[i, 'Target HR'] = 1
            else:
                team_df.loc[i, 'Target HR'] = 0
            
            # add "Next Throw" column
            team_df.loc[i, "Next Throw"] = team_df.loc[next_i, "Thr"]
        
    
    # Append team_df to df list
    batting_dfs.append(team_df)
    sleep(5)

print(len(batting_dfs))
# Out:
# ARI
# ATL
# BAL
# BOS
# CHC
# CHW
# CIN
# CLE
# COL
# DET
# MIA
# HOU
# KCR
# LAA
# LAD
# MIL
# MIN
# NYM
# NYY
# OAK
# PHI
# PIT
# SDP
# SFG
# SEA
# STL
# TBR
# TEX
# TOR
# WSN
# 30

# %%
# Combine all team_dfs into one

batting_2022_df = pd.concat(batting_dfs)
batting_2022_df = batting_2022_df.reset_index(drop=True)
batting_2022_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4860 entries, 0 to 4859
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Rk                    4860 non-null   object
#  1   Gtm                   4860 non-null   int64
#  2   Date                  4860 non-null   object
#  3   Unnamed: 3            2430 non-null   object
#  4   Opp                   4860 non-null   object
#  5   Rslt                  4860 non-null   object
#  6   PA                    4860 non-null   object
#  7   AB                    4860 non-null   object
#  8   R                     4860 non-null   object
#  9   H                     4860 non-null   object
#  10  2B                    4860 non-null   object
#  11  3B                    4860 non-null   object
#  12  HR                    4860 non-null   int64
#  13  RBI                   4860 non-null   object
#  14  BB                    4860 non-null   object
#  15  IBB                   4860 non-null   object
#  16  SO                    4860 non-null   object
#  17  HBP                   4860 non-null   object
#  18  SH                    4860 non-null   object
#  19  SF                    4860 non-null   object
#  20  ROE                   4860 non-null   object
#  21  GDP                   4860 non-null   object
#  22  SB                    4860 non-null   object
#  23  CS                    4860 non-null   object
#  24  BA                    4860 non-null   object
#  25  OBP                   4860 non-null   object
#  26  SLG                   4860 non-null   object
#  27  OPS                   4860 non-null   object
#  28  LOB                   4860 non-null   object
#  29  #                     4860 non-null   object
#  30  Thr                   4860 non-null   object
#  31  Opp. Starter (GmeSc)  4860 non-null   object
#  32  Team                  4860 non-null   object
#  33  Target HR             4830 non-null   float64
#  34  Next Throw            4830 non-null   object
# dtypes: float64(1), int64(2), object(32)
# memory usage: 1.3+ MB

# %%
# Drop 'Rk', create 'Home/Away'

batting_2022_df = batting_2022_df.drop(columns="Rk", axis=1)
batting_2022_df = batting_2022_df.rename(columns={"Unnamed: 3":"Home/Away"})
batting_2022_df['Home/Away'] = batting_2022_df['Home/Away'].fillna("H")
batting_2022_df.head()
# Out:
#    Gtm    Date Home/Away  Opp    Rslt  PA  AB  R  H 2B  ...   OBP   SLG   OPS  \
# 0    1   Apr 7         H  SDP   W,4-2  34  26  4  3  0  ...  .324  .231  .554
# 1    2   Apr 8         H  SDP   L,0-3  30  29  0  2  0  ...  .219  .145  .364
# 2    3   Apr 9         H  SDP   L,2-5  33  31  2  5  2  ...  .216  .209  .426
# 3    4  Apr 10         H  SDP  L,5-10  39  30  5  5  1  ...  .257  .259  .516
# 4    5  Apr 12         H  HOU   L,1-2  36  30  1  4  1  ...  .257  .260  .518
#
#   LOB   # Thr Opp. Starter (GmeSc) Team Target HR Next Throw
# 0   6  12   R        Y.Darvish(71)  ARI       0.0          L
# 1   3  11   L         S.Manaea(83)  ARI       1.0          R
# 2   4  10   R       J.Musgrove(62)  ARI       1.0          R
# 3   7  10   R       N.Crismatt(58)  ARI       1.0          R
# 4   8  13   R         L.Garcia(57)  ARI       0.0          L
#
# [5 rows x 34 columns]

# %%
# Create 'Venue' column
for i in range(len(batting_2022_df)):
    if batting_2022_df.loc[i, 'Home/Away'] == "H":
        batting_2022_df.loc[i, 'Venue'] = batting_2022_df.loc[i, 'Team']
    else:
        batting_2022_df.loc[i, 'Venue'] = batting_2022_df.loc[i, 'Opp']

batting_2022_df.head(20)
# Out:
#     Gtm        Date Home/Away  Opp    Rslt  PA  AB   R   H 2B  ...   SLG  \
# 0     1       Apr 7         H  SDP   W,4-2  34  26   4   3  0  ...  .231
# 1     2       Apr 8         H  SDP   L,0-3  30  29   0   2  0  ...  .145
# 2     3       Apr 9         H  SDP   L,2-5  33  31   2   5  2  ...  .209
# 3     4      Apr 10         H  SDP  L,5-10  39  30   5   5  1  ...  .259
# 4     5      Apr 12         H  HOU   L,1-2  36  30   1   4  1  ...  .260
# 5     6      Apr 13         H  HOU   W,3-2  47  33   3   6  0  ...  .246
# 6     7      Apr 15         @  NYM  L,3-10  35  29   3   3  2  ...  .250
# 7     8      Apr 16         @  NYM   W,3-2  40  36   3   9  2  ...  .270
# 8     9      Apr 17         @  NYM   L,0-5  36  32   0   5  2  ...  .264
# 9    10  Apr 19 (1)         @  WSN   L,1-6  34  31   1   6  2  ...  .274
# 10   11  Apr 19 (2)         @  WSN   L,0-1  35  32   0   5  1  ...  .265
# 11   12      Apr 20         @  WSN  W,11-2  42  35  11  10  2  ...  .281
# 12   13      Apr 21         @  WSN   W,4-3  39  35   4   9  1  ...  .303
# 13   14      Apr 22         H  NYM   L,5-6  40  36   5   8  3  ...  .317
# 14   15      Apr 23         H  NYM   W,5-2  38  34   5  11  2  ...  .326
# 15   16      Apr 24         H  NYM   L,2-6  34  33   2   6  2  ...  .326
# 16   17      Apr 25         H  LAD   L,0-4  31  30   0   3  0  ...  .314
# 17   18      Apr 26         H  LAD   W,5-3  33  29   5   4  1  ...  .312
# 18   19      Apr 27         H  LAD   W,3-1  31  26   3   2  0  ...  .307
# 19   20      Apr 28         @  STL   L,3-8  37  33   3   6  2  ...  .308
#
#      OPS LOB   # Thr Opp. Starter (GmeSc) Team Target HR Next Throw Venue
# 0   .554   6  12   R        Y.Darvish(71)  ARI       0.0          L   ARI
# 1   .364   3  11   L         S.Manaea(83)  ARI       1.0          R   ARI
# 2   .426   4  10   R       J.Musgrove(62)  ARI       1.0          R   ARI
# 3   .516   7  10   R       N.Crismatt(58)  ARI       1.0          R   ARI
# 4   .518   8  13   R         L.Garcia(57)  ARI       0.0          L   ARI
# 5   .532  17  13   L         F.Valdez(49)  ARI       1.0          R   ARI
# 6   .532   5  12   R        C.Bassitt(68)  ARI       1.0          R   NYM
# 7   .558  10  10   R       C.Carrasco(67)  ARI       0.0          L   NYM
# 8   .548   9  11   L       D.Peterson(59)  ARI       1.0          R   NYM
# 9   .555   6  11   R           J.Gray(64)  ARI       0.0          R   WSN
# 10  .543   8  12   R           J.Adon(70)  ARI       1.0          R   WSN
# 11  .563   4  12   R          E.Fedde(20)  ARI       1.0          L   WSN
# 12  .590   8  14   L         J.Rogers(36)  ARI       1.0          L   WSN
# 13  .603   6  13   L       D.Peterson(61)  ARI       0.0          R   ARI
# 14  .617   9  10   R       T.Williams(26)  ARI       1.0          R   ARI
# 15  .613   5  12   R         T.Megill(62)  ARI       0.0          R   ARI
# 16  .592   4  13   R        W.Buehler(91)  ARI       1.0          R   ARI
# 17  .588   4  12   R       T.Gonsolin(50)  ARI       1.0          L   ARI
# 18  .580   4  10   L          J.Urías(68)  ARI       1.0          R   ARI
# 19  .581   7   9   R         D.Hudson(71)  ARI       0.0          R   STL
#
# [20 rows x 35 columns]

# %%
# New df with columns to use
feature_cols = ['Gtm', 'Date', 'Team', 'Opp', 'Home/Away', 'Venue', 'BA', 'OBP', 'SLG', 'OPS', 'Next Throw', 'Target HR']
batting_features_df = batting_2022_df[feature_cols]
batting_features_df.head()
# Out:
#    Gtm    Date Team  Opp Home/Away Venue    BA   OBP   SLG   OPS Next Throw  \
# 0    1   Apr 7  ARI  SDP         H   ARI  .115  .324  .231  .554          L
# 1    2   Apr 8  ARI  SDP         H   ARI  .091  .219  .145  .364          R
# 2    3   Apr 9  ARI  SDP         H   ARI  .116  .216  .209  .426          R
# 3    4  Apr 10  ARI  SDP         H   ARI  .129  .257  .259  .516          R
# 4    5  Apr 12  ARI  HOU         H   ARI  .130  .257  .260  .518          L
#
#    Target HR
# 0        0.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        0.0

# %%
# Drop NA to remove each teams last game since it has no target HR to predict
batting_features_df = batting_features_df.dropna()
batting_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4830 entries, 0 to 4858
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gtm         4830 non-null   int64
#  1   Date        4830 non-null   object
#  2   Team        4830 non-null   object
#  3   Opp         4830 non-null   object
#  4   Home/Away   4830 non-null   object
#  5   Venue       4830 non-null   object
#  6   BA          4830 non-null   object
#  7   OBP         4830 non-null   object
#  8   SLG         4830 non-null   object
#  9   OPS         4830 non-null   object
#  10  Next Throw  4830 non-null   object
#  11  Target HR   4830 non-null   float64
# dtypes: float64(1), int64(1), object(10)
# memory usage: 490.5+ KB
