# %%
import pandas as pd

# %%
# Read in the CSV file
csv_file_path = "Resources/nhl-2023-UTC.csv"
nhl_df = pd.read_csv(csv_file_path)
nhl_df.head()
# Out:
#    Match Number  Round Number              Date          Location  \
# 0             1             1  10/10/2023 21:30      Amalie Arena
# 1             2             1  11/10/2023 00:00  PPG Paints Arena
# 2             3             1  11/10/2023 02:30    T-Mobile Arena
# 3             4             1  11/10/2023 23:00         PNC Arena
# 4             5             1  11/10/2023 23:00  Scotiabank Arena
#
#               Home Team            Away Team  Result
# 0   Tampa Bay Lightning  Nashville Predators     NaN
# 1   Pittsburgh Penguins   Chicago Blackhawks     NaN
# 2  Vegas Golden Knights       Seattle Kraken     NaN
# 3   Carolina Hurricanes      Ottawa Senators     NaN
# 4   Toronto Maple Leafs   Montréal Canadiens     NaN

# %%
#Split date column into date and time
nhl_df[['Date', 'Time']] = nhl_df['Date'].str.split(pat=' ', n=1, expand=True)

nhl_df.head()
# Out:
#    Match Number  Round Number        Date          Location  \
# 0             1             1  10/10/2023      Amalie Arena
# 1             2             1  11/10/2023  PPG Paints Arena
# 2             3             1  11/10/2023    T-Mobile Arena
# 3             4             1  11/10/2023         PNC Arena
# 4             5             1  11/10/2023  Scotiabank Arena
#
#               Home Team            Away Team  Result   Time
# 0   Tampa Bay Lightning  Nashville Predators     NaN  21:30
# 1   Pittsburgh Penguins   Chicago Blackhawks     NaN  00:00
# 2  Vegas Golden Knights       Seattle Kraken     NaN  02:30
# 3   Carolina Hurricanes      Ottawa Senators     NaN  23:00
# 4   Toronto Maple Leafs   Montréal Canadiens     NaN  23:00

# %%
#change date format
nhl_df['Date'] = pd.to_datetime(nhl_df['Date'], format='%d/%m/%Y')
nhl_df['Date'] = nhl_df['Date'].dt.strftime('%m/%d/%Y')
nhl_df.head()
# Out:
#    Match Number  Round Number        Date          Location  \
# 0             1             1  10/10/2023      Amalie Arena
# 1             2             1  10/11/2023  PPG Paints Arena
# 2             3             1  10/11/2023    T-Mobile Arena
# 3             4             1  10/11/2023         PNC Arena
# 4             5             1  10/11/2023  Scotiabank Arena
#
#               Home Team            Away Team  Result   Time
# 0   Tampa Bay Lightning  Nashville Predators     NaN  21:30
# 1   Pittsburgh Penguins   Chicago Blackhawks     NaN  00:00
# 2  Vegas Golden Knights       Seattle Kraken     NaN  02:30
# 3   Carolina Hurricanes      Ottawa Senators     NaN  23:00
# 4   Toronto Maple Leafs   Montréal Canadiens     NaN  23:00

# %%
#changing time zone to central time zone (CST)
nhl_df['Time'] = pd.to_datetime(nhl_df['Time'], utc=True)
# Convert the time column to CST time zone
nhl_df['CST Gametime'] = nhl_df['Time'].dt.tz_convert('America/Chicago')

# Only show the time in 12 hr format
nhl_df['CST Gametime'] = nhl_df['CST Gametime'].apply(lambda x: x.strftime('%I:%M %p'))

# Print the DataFrame
nhl_df.head()
# Out:
#    Match Number  Round Number        Date          Location  \
# 0             1             1  10/10/2023      Amalie Arena
# 1             2             1  10/11/2023  PPG Paints Arena
# 2             3             1  10/11/2023    T-Mobile Arena
# 3             4             1  10/11/2023         PNC Arena
# 4             5             1  10/11/2023  Scotiabank Arena
#
#               Home Team            Away Team  Result  \
# 0   Tampa Bay Lightning  Nashville Predators     NaN
# 1   Pittsburgh Penguins   Chicago Blackhawks     NaN
# 2  Vegas Golden Knights       Seattle Kraken     NaN
# 3   Carolina Hurricanes      Ottawa Senators     NaN
# 4   Toronto Maple Leafs   Montréal Canadiens     NaN
#
#                        Time CST Gametime
# 0 2023-08-09 21:30:00+00:00     04:30 PM
# 1 2023-08-09 00:00:00+00:00     07:00 PM
# 2 2023-08-09 02:30:00+00:00     09:30 PM
# 3 2023-08-09 23:00:00+00:00     06:00 PM
# 4 2023-08-09 23:00:00+00:00     06:00 PM

# %%
#Drop old time column
nhl_df = nhl_df.drop(columns=['Time'])
nhl_df.head()
# Out:
#    Match Number  Round Number        Date          Location  \
# 0             1             1  10/10/2023      Amalie Arena
# 1             2             1  10/11/2023  PPG Paints Arena
# 2             3             1  10/11/2023    T-Mobile Arena
# 3             4             1  10/11/2023         PNC Arena
# 4             5             1  10/11/2023  Scotiabank Arena
#
#               Home Team            Away Team  Result CST Gametime
# 0   Tampa Bay Lightning  Nashville Predators     NaN     04:30 PM
# 1   Pittsburgh Penguins   Chicago Blackhawks     NaN     07:00 PM
# 2  Vegas Golden Knights       Seattle Kraken     NaN     09:30 PM
# 3   Carolina Hurricanes      Ottawa Senators     NaN     06:00 PM
# 4   Toronto Maple Leafs   Montréal Canadiens     NaN     06:00 PM

# %%
nhl_df = nhl_df.drop(columns=["Match Number"])
nhl_df.head()
# Out:
#    Round Number        Date          Location             Home Team  \
# 0             1  10/10/2023      Amalie Arena   Tampa Bay Lightning
# 1             1  10/11/2023  PPG Paints Arena   Pittsburgh Penguins
# 2             1  10/11/2023    T-Mobile Arena  Vegas Golden Knights
# 3             1  10/11/2023         PNC Arena   Carolina Hurricanes
# 4             1  10/11/2023  Scotiabank Arena   Toronto Maple Leafs
#
#              Away Team  Result CST Gametime
# 0  Nashville Predators     NaN     04:30 PM
# 1   Chicago Blackhawks     NaN     07:00 PM
# 2       Seattle Kraken     NaN     09:30 PM
# 3      Ottawa Senators     NaN     06:00 PM
# 4   Montréal Canadiens     NaN     06:00 PM

# %%
# Rename column
new_column_name = 'Week Number'
nhl_df.rename(columns={'Round Number': new_column_name}, inplace=True)
nhl_df.head()
# Out:
#    Week Number        Date          Location             Home Team  \
# 0            1  10/10/2023      Amalie Arena   Tampa Bay Lightning
# 1            1  10/11/2023  PPG Paints Arena   Pittsburgh Penguins
# 2            1  10/11/2023    T-Mobile Arena  Vegas Golden Knights
# 3            1  10/11/2023         PNC Arena   Carolina Hurricanes
# 4            1  10/11/2023  Scotiabank Arena   Toronto Maple Leafs
#
#              Away Team  Result CST Gametime
# 0  Nashville Predators     NaN     04:30 PM
# 1   Chicago Blackhawks     NaN     07:00 PM
# 2       Seattle Kraken     NaN     09:30 PM
# 3      Ottawa Senators     NaN     06:00 PM
# 4   Montréal Canadiens     NaN     06:00 PM

# %%
team_df = pd.read_csv('Resources/team.csv')

# Take only nfl teams and reset index

nhl_teams_df = team_df[team_df['league_id'] == 3].reset_index()

nhl_teams_df.head()
# Out:
#    index  team_id                 team  venue_id  league_id
# 0     62       63  Tampa Bay Lightning        60          3
# 1     63       64         Dallas Stars         1          3
# 2     64       65   Colorado Avalanche         4          3
# 3     65       66   Montréal Canadiens        61          3
# 4     66       67  Nashville Predators        62          3

# %%
# Confirm all team names match with mlb_teams_df
team_nf = []

for i in range(len(nhl_df)):
    home_team = nhl_df.loc[i, 'Home Team']
    away_team = nhl_df.loc[i, 'Away Team']
    
    if home_team not in list(nhl_teams_df['team']):
        if home_team not in team_nf:
            print(f"{home_team} not found. Adding to tracker...")
            team_nf.append(home_team)
    
    if away_team not in list(nhl_teams_df['team']):
        if away_team not in team_nf:
            print(f"{away_team} not found. Adding to tracker...")
            team_nf.append(away_team)
            
print(team_nf)
# Out:
# []

# %%
# Assign each row a 'home_id', 'away_id', and 'venue_id'
nhl_df['home_id'] = ''
nhl_df['away_id'] = ''
nhl_df['venue_id'] = ''

for i in range(len(nhl_df)):
    home_team = nhl_teams_df[nhl_teams_df['team'] == nhl_df.loc[i, 'Home Team']]
    away_team = nhl_teams_df[nhl_teams_df['team'] == nhl_df.loc[i, 'Away Team']]
    
    nhl_df.loc[i, 'home_id'] = int(home_team['team_id'])
    nhl_df.loc[i, 'venue_id'] = int(home_team['venue_id'])
    nhl_df.loc[i, 'away_id'] = int(away_team['team_id'])

nhl_df
# Out:
#       Week Number        Date               Location             Home Team  \
# 0               1  10/10/2023           Amalie Arena   Tampa Bay Lightning
# 1               1  10/11/2023       PPG Paints Arena   Pittsburgh Penguins
# 2               1  10/11/2023         T-Mobile Arena  Vegas Golden Knights
# 3               1  10/11/2023              PNC Arena   Carolina Hurricanes
# 4               1  10/11/2023       Scotiabank Arena   Toronto Maple Leafs
# ...           ...         ...                    ...                   ...
# 1307           26  04/19/2024     Canada Life Centre         Winnipeg Jets
# 1308           26  04/19/2024  Scotiabank Saddledome        Calgary Flames
# 1309           26  04/19/2024             Ball Arena    Colorado Avalanche
# 1310           26  04/19/2024         T-Mobile Arena  Vegas Golden Knights
# 1311           26  04/19/2024       Crypto.com Arena     Los Angeles Kings
#
#                 Away Team  Result CST Gametime home_id away_id venue_id
# 0     Nashville Predators     NaN     04:30 PM      63      67       60
# 1      Chicago Blackhawks     NaN     07:00 PM      82      92       73
# 2          Seattle Kraken     NaN     09:30 PM      90      71       79
# 3         Ottawa Senators     NaN     06:00 PM      81      69       72
# 4      Montréal Canadiens     NaN     06:00 PM      87      66       20
# ...                   ...     ...          ...     ...     ...      ...
# 1307    Vancouver Canucks     NaN     07:00 PM      68      84       63
# 1308      San Jose Sharks     NaN     08:00 PM      88      86       78
# 1309      Edmonton Oilers     NaN     08:30 PM      65      85        4
# 1310        Anaheim Ducks     NaN     09:00 PM      90      76       79
# 1311   Chicago Blackhawks     NaN     09:30 PM      72      92        8
#
# [1312 rows x 10 columns]

# %%
nhl_formatted_df = nhl_df[["Date", "CST Gametime", "home_id", "away_id", "venue_id"]]
nhl_formatted_df = nhl_formatted_df.rename(columns={"Date":"event_date",
                                                   "CST Gametime": "event_time_cst"})
nhl_formatted_df.head()
# Out:
#    event_date event_time_cst home_id away_id venue_id
# 0  10/10/2023       04:30 PM      63      67       60
# 1  10/11/2023       07:00 PM      82      92       73
# 2  10/11/2023       09:30 PM      90      71       79
# 3  10/11/2023       06:00 PM      81      69       72
# 4  10/11/2023       06:00 PM      87      66       20

# %%
nhl_formatted_df.to_csv("Resources/events/nhl_events.csv")
